# %% [markdown]
# <a href="https://colab.research.google.com/github/DIPANJAN001/Dipanjanpatra/blob/master/best5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install Boruta
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from boruta import BorutaPy
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import concatenate
from keras import Model
from keras.layers import Input
from keras.layers import Bidirectional
from keras import layers
from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_classification
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.layers import LeakyReLU
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import BatchNormalization
from keras.models import load_model
from keras.layers import Input
from sklearn.decomposition import PCA
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Boruta in /usr/local/lib/python3.7/dist-packages (0.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from Boruta) (1.21.6)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from Boruta) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from Boruta) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.17.1->Boruta) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.17.1->Boruta) (3.1.0)

# %%
def lstm_data_transform(x_data, y_data, num_steps):
    """ Changes data to the format for LSTM training 
for sliding window approach """
    # Prepare the list for the transformed data
    X, y = list(), list()
    # Loop of the entire data set
    for i in range(x_data.shape[0]):
        # compute a new (sliding window) index
        end_ix = i + num_steps
        # if index is larger than the size of the dataset, we stop
        if end_ix >= x_data.shape[0]:
            break
        # Get a sequence of data for x
        seq_X = x_data[i:end_ix]
        # Get only the last element of the sequency for y
        seq_y = y_data[end_ix]
        # Append the list with sequencies
        X.append(seq_X)
        y.append(seq_y)
    # Make final arrays
    x_array = np.array(X)
    y_array = np.array(y)
    return x_array, y_array

# %%
df=pd.read_excel("/content/pv_02 _.xlsx")
weather_input1=df.drop('power_normed',axis=1)
weather_input=weather_input1.drop('time_idx',axis=1)
solpow=df['power_normed']

# %%
rfc = RandomForestRegressor(random_state=1, n_estimators=1000, max_depth=5)
boruta_selector = BorutaPy(rfc, n_estimators='auto', verbose=2, random_state=1)
boruta_selector.fit(np.array(weather_input), np.array(solpow))
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	5
# Tentative: 	18
# Rejected: 	26
# Iteration: 	9 / 100
# Confirmed: 	5
# Tentative: 	18
# Rejected: 	26
# Iteration: 	10 / 100
# Confirmed: 	5
# Tentative: 	18
# Rejected: 	26
# Iteration: 	11 / 100
# Confirmed: 	5
# Tentative: 	18
# Rejected: 	26
# Iteration: 	12 / 100
# Confirmed: 	8
# Tentative: 	15
# Rejected: 	26
# Iteration: 	13 / 100
# Confirmed: 	8
# Tentative: 	14
# Rejected: 	27
# Iteration: 	14 / 100
# Confirmed: 	8
# Tentative: 	14
# Rejected: 	27
# Iteration: 	15 / 100
# Confirmed: 	8
# Tentative: 	14
# Rejected: 	27
# Iteration: 	16 / 100
# Confirmed: 	11
# Tentative: 	11
# Rejected: 	27
# Iteration: 	17 / 100
# Confirmed: 	11
# Tentative: 	11
# Rejected: 	27
# Iteration: 	18 / 100
# Confirmed: 	11
# Tentative: 	11
# Rejected: 	27
# Iteration: 	19 / 100
# Confirmed: 	12
# Tentative: 	10
# Rejected: 	27
# Iteration: 	20 / 100
# Confirmed: 	12
# Tentative: 	10
# Rejected: 	27
# Iteration: 	21 / 100
# Confirmed: 	12
# Tentative: 	10
# Rejected: 	27
# Iteration: 	22 / 100
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	27
# Iteration: 	23 / 100
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	27
# Iteration: 	24 / 100
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	27
# Iteration: 	25 / 100
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	27
# Iteration: 	26 / 100
# Confirmed: 	14
# Tentative: 	8
# Rejected: 	27
# Iteration: 	27 / 100
# Confirmed: 	14
# Tentative: 	8
# Rejected: 	27
# Iteration: 	28 / 100
# Confirmed: 	14
# Tentative: 	8
# Rejected: 	27
# Iteration: 	29 / 100
# Confirmed: 	15
# Tentative: 	7
# Rejected: 	27
# Iteration: 	30 / 100
# Confirmed: 	15
# Tentative: 	7
# Rejected: 	27
# Iteration: 	31 / 100
# Confirmed: 	15
# Tentative: 	7
# Rejected: 	27
# Iteration: 	32 / 100
# Confirmed: 	15
# Tentative: 	7
# Rejected: 	27
# Iteration: 	33 / 100
# Confirmed: 	15
# Tentative: 	7
# Rejected: 	27
# Iteration: 	34 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	35 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	36 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	37 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	38 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	39 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	40 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	41 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	42 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	43 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	44 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	45 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	46 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	47 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	48 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	49 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	50 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	51 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	52 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	53 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	54 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	55 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	56 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	57 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	58 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	59 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	60 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	61 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	62 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	63 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	64 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	65 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	66 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	67 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	68 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	69 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	70 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	71 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	72 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	73 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	74 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	75 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	76 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	77 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	78 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	79 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	80 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	81 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	82 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	27
# Iteration: 	83 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	27
# Iteration: 	84 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	27
# Iteration: 	85 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	27
# Iteration: 	86 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	27
# Iteration: 	87 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	27
# Iteration: 	88 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	27
# Iteration: 	89 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	27
# Iteration: 	90 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	27
# Iteration: 	91 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	27
# Iteration: 	92 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	27
# Iteration: 	93 / 100
# Confirmed: 	17
# Tentative: 	4
# Rejected: 	28
# Iteration: 	94 / 100
# Confirmed: 	17
# Tentative: 	4
# Rejected: 	28
# Iteration: 	95 / 100
# Confirmed: 	17
# Tentative: 	4
# Rejected: 	28
# Iteration: 	96 / 100
# Confirmed: 	17
# Tentative: 	4
# Rejected: 	28
# Iteration: 	97 / 100
# Confirmed: 	17
# Tentative: 	4
# Rejected: 	28
# Iteration: 	98 / 100
# Confirmed: 	17
# Tentative: 	4
# Rejected: 	28
# Iteration: 	99 / 100
# Confirmed: 	17
# Tentative: 	4
# Rejected: 	28
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	17
# Tentative: 	3
# Rejected: 	28
# BorutaPy(estimator=RandomForestRegressor(max_depth=5, n_estimators=129,
#                                          random_state=RandomState(MT19937) at 0x7F46BAD4F380),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x7F46BAD4F380, verbose=2)

# %%
X_important_train = boruta_selector.transform(np.array(weather_input))
num_steps = 2
# training set
(x_transformed_train,
 y_transformed_train) = lstm_data_transform(X_important_train,solpow , num_steps=num_steps)
assert x_transformed_train.shape[0] == y_transformed_train.shape[0]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_transformed_train,y_transformed_train,test_size=0.25, random_state=42,shuffle=False)
#X_train_,X_val,y_train_,y_val=train_test_split(X_train,y_train,test_size=0.2, random_state=42,shuffle=False)
inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))

# %%
inputs1
# Out:
# <KerasTensor: shape=(None, 2, 17) dtype=float32 (created by layer 'input_2')>

# %%
from keras import optimizers

# %%
opt=optimizers.Adam(learning_rate=0.001)

# %%
'''def define_model_():


  # firs
  fe1_0 = LSTM(34, activation='relu',return_sequences = True)(inputs1)
  fe1_1 = Dropout(0.3)(fe1_0)
  #fe1_2 = LSTM(16, activation='relu',return_sequences = True)(fe1_1)
  #fe1_3= Dropout(0.2)(fe1_2)
  fe1_4=LSTM(12, activation='relu')(fe1_1)
  out1_1=Dense(1, activation='relu')(fe1_4)



  fe2_0 = LSTM(40, activation='relu',return_sequences = True)(inputs1)
  fe2_1 = Dropout(0.4)(fe2_0)
  #fe2_2 = LSTM(16, activation='relu',return_sequences = True)(fe2_1)
  #fe2_3= Dropout(0.5)(fe2_2)
  fe2_4=LSTM(32, activation='relu')(fe2_1)
  out2_1=Dense(1, activation='relu')(fe2_4)

  fe3_0 = LSTM(24, activation='relu',return_sequences = True)(inputs1)
  fe3_1 = Dropout(0.6)(fe3_0)
  #fe3_2 = LSTM(8, activation='relu',return_sequences = True)(fe3_1)
  #fe3_3= Dropout(0.5)(fe3_2)
  fe3_4=LSTM(16, activation='relu')(fe3_1)
  out3_1=Dense(1, activation='relu')(fe3_4)
 
 

  #output = layers.average([ out1_1, out2_1, out3_1])
  merged3 = concatenate([out1_1,out2_1,out3_1], name='concat3')
  output = Dense(1, activation='relu')( merged3)
  

  model = Model(inputs=[inputs1], outputs=[output])
  model.compile(optimizer=opt,loss='mean_squared_error',metrics=['mse'])
 
  return model
mdl=define_model_()
history=mdl.fit(X_train, y_train, epochs = 200,validation_split=0.2,batch_size = 64)
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
y=mdl.predict(X_test)
plt.scatter(y,y_test)
plt.show()
df = pd.DataFrame()
df['time']=[i for i in range(len(y))]
df['Actual']=y_test
df['Predicted']=y
plt.plot(df['time'],df['Actual'])
plt.plot(df['time'],df['Predicted'])
plt.show()'''
# Out:
# "def define_model_():\n\n\n  # firs\n  fe1_0 = LSTM(34, activation='relu',return_sequences = True)(inputs1)\n  fe1_1 = Dropout(0.3)(fe1_0)\n  #fe1_2 = LSTM(16, activation='relu',return_sequences = True)(fe1_1)\n  #fe1_3= Dropout(0.2)(fe1_2)\n  fe1_4=LSTM(12, activation='relu')(fe1_1)\n  out1_1=Dense(1, activation='relu')(fe1_4)\n\n\n\n  fe2_0 = LSTM(40, activation='relu',return_sequences = True)(inputs1)\n  fe2_1 = Dropout(0.4)(fe2_0)\n  #fe2_2 = LSTM(16, activation='relu',return_sequences = True)(fe2_1)\n  #fe2_3= Dropout(0.5)(fe2_2)\n  fe2_4=LSTM(32, activation='relu')(fe2_1)\n  out2_1=Dense(1, activation='relu')(fe2_4)\n\n  fe3_0 = LSTM(24, activation='relu',return_sequences = True)(inputs1)\n  fe3_1 = Dropout(0.6)(fe3_0)\n  #fe3_2 = LSTM(8, activation='relu',return_sequences = True)(fe3_1)\n  #fe3_3= Dropout(0.5)(fe3_2)\n  fe3_4=LSTM(16, activation='relu')(fe3_1)\n  out3_1=Dense(1, activation='relu')(fe3_4)\n \n \n\n  #output = layers.average([ out1_1, out2_1, out3_1])\n  merged3 = concatenate([out1_1,out2_1,out3_1], name='concat3')\n  output = Dense(1, activation='relu')( merged3)\n  \n\n  model = Model(inputs=[inputs1], outputs=[output])\n  model.compile(optimizer=opt,loss='mean_squared_error',metrics=['mse'])\n \n  return model\nmdl=define_model_()\nhistory=mdl.fit(X_train, y_train, epochs = 200,validation_split=0.2,batch_size = 64)\nimport matplotlib.pyplot as plt\nplt.plot(history.history['loss'], label='train')\nplt.plot(history.history['val_loss'], label='val')\nplt.legend()\nplt.show()\ny=mdl.predict(X_test)\nplt.scatter(y,y_test)\nplt.show()\ndf = pd.DataFrame()\ndf['time']=[i for i in range(len(y))]\ndf['Actual']=y_test\ndf['Predicted']=y\nplt.plot(df['time'],df['Actual'])\nplt.plot(df['time'],df['Predicted'])\nplt.show()"

# %%
#print(np.sqrt(mean_squared_error(y,y_test)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-5123fda47712> in <module>
# ----> 1 print(np.sqrt(mean_squared_error(y,y_test)))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     437     """
#     438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 439         y_true, y_pred, multioutput
#     440     )
#     441     check_consistent_length(y_true, y_pred, sample_weight)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
# --> 334             % [int(l) for l in lengths]
#     335         )
#     336
#
# ValueError: Found input variables with inconsistent numbers of samples: [1535, 1569]

# %%
def define_model():


  # firs
  fe1_0 = LSTM(208, activation='relu',return_sequences = True)(inputs1)
  fe1_1 = Dropout(0.5)(fe1_0)
  fe1_2 = LSTM(24, activation='relu',return_sequences = True)(fe1_1)
  fe1_3= Dropout(0.2)(fe1_2)
  fe1_4=LSTM(30, activation='relu')(fe1_3)
  out1_1=Dense(1, activation='relu')(fe1_4)



  fe2_0 = LSTM(208, activation='relu',return_sequences = True)(inputs1)
  fe2_1 = Dropout(0.6)(fe2_0)
  fe2_2 = LSTM(60, activation='relu',return_sequences = True)(fe2_1)
  fe2_3= Dropout(0.5)(fe2_2)
  fe2_4=LSTM(4, activation='relu')(fe2_3)
  out2_1=Dense(1, activation='relu')(fe2_4)

  fe3_0 =LSTM(104, activation='relu',return_sequences = True)(inputs1)
  fe3_1 = Dropout(0.6)(fe3_0)
  fe3_2 = LSTM(96, activation='relu',return_sequences = True)(fe3_1)
  fe3_3= Dropout(0.5)(fe3_2)
  fe3_4=LSTM(8, activation='relu')(fe3_3)#16
  out3_1=Dense(1, activation='relu')(fe3_4)
 
 

  #output = layers.average([ out1_1, out2_1, out3_1])
  merged3 = concatenate([out1_1,out2_1,out3_1], name='concat3')
  output = Dense(1, activation='relu')( merged3)
  

  model = Model(inputs=[inputs1], outputs=[output])
  model.compile(optimizer=opt,loss='mean_squared_error',metrics=['mse'])
 
  return model
mdl=define_model()
history=mdl.fit(X_train, y_train, epochs = 100,validation_split=0.2,batch_size =64)
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
y=mdl.predict(X_test)
plt.scatter(y,y_test)
plt.show()
df = pd.DataFrame()
df['time']=[i for i in range(len(y))]
df['Actual']=y_test
df['Predicted']=y
plt.plot(df['time'],df['Actual'])
plt.plot(df['time'],df['Predicted'])
plt.show()
print(np.sqrt(mean_squared_error(y,y_test)))
# Out:
# Epoch 1/100
# 59/59 [==============================] - 11s 42ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 2/100
# 59/59 [==============================] - 2s 41ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 3/100
# 59/59 [==============================] - 3s 50ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 4/100
# 59/59 [==============================] - 3s 51ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 5/100
# 59/59 [==============================] - 2s 41ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 6/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 7/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 8/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 9/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 10/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 11/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 12/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 13/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 14/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 15/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 16/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 17/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 18/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 19/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 20/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 21/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 22/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 23/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 24/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 25/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 26/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 27/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 28/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 29/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 30/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 31/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 32/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 33/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 34/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 35/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 36/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 37/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 38/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 39/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 40/100
# 59/59 [==============================] - 2s 31ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 41/100
# 59/59 [==============================] - 2s 33ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 42/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 43/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 44/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 45/100
# 59/59 [==============================] - 1s 25ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 46/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 47/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 48/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 49/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 50/100
# 59/59 [==============================] - 1s 25ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 51/100
# 59/59 [==============================] - 1s 25ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 52/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 53/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 54/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 55/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 56/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 57/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 58/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 59/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 60/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 61/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 62/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 63/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 64/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 65/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 66/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 67/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 68/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 69/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 70/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 71/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 72/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 73/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 74/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 75/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 76/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 77/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 78/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 79/100
# 59/59 [==============================] - 1s 25ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 80/100
# 59/59 [==============================] - 2s 40ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 81/100
# 59/59 [==============================] - 2s 36ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 82/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 83/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 84/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 85/100
# 59/59 [==============================] - 1s 25ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 86/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 87/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 88/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 89/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 90/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 91/100
# 59/59 [==============================] - 1s 25ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 92/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 93/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 94/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 95/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 96/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 97/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 98/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 99/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 100/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0529 - val_mse: 0.0529
# 50/50 [==============================] - 1s 4ms/step
# 0.20207554199263292

# %%
def define_model():


  # firs
  fe1_0 = LSTM(208, activation='relu',return_sequences = True)(inputs1)
  fe1_1 = Dropout(0.5)(fe1_0)
  fe1_2 = LSTM(24, activation='relu',return_sequences = True)(fe1_1)
  fe1_3= Dropout(0.5)(fe1_2)
  fe1_4=LSTM(30, activation='relu')(fe1_3)
  out1_1=Dense(1, activation='relu')(fe1_4)



  fe2_0 = LSTM(208, activation='relu',return_sequences = True)(inputs1)
  fe2_1 = Dropout(0.5)(fe2_0)
  fe2_2 = LSTM(60, activation='relu',return_sequences = True)(fe2_1)
  fe2_3= Dropout(0.5)(fe2_2)
  fe2_4=LSTM(4, activation='relu')(fe2_3)
  out2_1=Dense(1, activation='relu')(fe2_4)

  fe3_0 =LSTM(104, activation='relu',return_sequences = True)(inputs1)
  fe3_1 = Dropout(0.6)(fe3_0)
  fe3_2 = LSTM(96, activation='relu',return_sequences = True)(fe3_1)
  fe3_3= Dropout(0.5)(fe3_2)
  fe3_4=LSTM(8, activation='relu')(fe3_3)#16
  out3_1=Dense(1, activation='relu')(fe3_4)
 
 

  output = layers.average([ out1_1, out2_1, out3_1])
  #merged3 = concatenate([out1_1,out2_1,out3_1], name='concat3')
  #output = Dense(1, activation='relu')( merged3)
  

  model = Model(inputs=[inputs1], outputs=[output])
  model.compile(optimizer=opt,loss='mean_squared_error',metrics=['mse'])
 
  return model
mdl=define_model()
history=mdl.fit(X_train, y_train, epochs = 100,validation_split=0.2,batch_size =64 )
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
y=mdl.predict(X_test)
plt.scatter(y,y_test)
plt.show()
df = pd.DataFrame()
df['time']=[i for i in range(len(y))]
df['Actual']=y_test
df['Predicted']=y
plt.plot(df['time'],df['Actual'])
plt.plot(df['time'],df['Predicted'])
plt.show()
print(np.sqrt(mean_squared_error(y,y_test)))
# Out:
# Epoch 1/100
# 59/59 [==============================] - 11s 42ms/step - loss: 0.0171 - mse: 0.0171 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 2/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 3/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 4/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 5/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 6/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 7/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 8/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 9/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 10/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 11/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 12/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 13/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 14/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 15/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 16/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 17/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 18/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 19/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 20/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 21/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 22/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 23/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 24/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 25/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 26/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 27/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 28/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 29/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 30/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 31/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 32/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 33/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 34/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 35/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 36/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 37/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 38/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 39/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 40/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 41/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 42/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 43/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 44/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 45/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 46/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 47/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 48/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 49/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 50/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 51/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 52/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 53/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 54/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 55/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 56/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 57/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 58/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 59/100
# 59/59 [==============================] - 2s 40ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 60/100
# 59/59 [==============================] - 2s 34ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 61/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 62/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 63/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 64/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 65/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 66/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 67/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 68/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 69/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 70/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 71/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 72/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 73/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 74/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 75/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 76/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 77/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 78/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 79/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 80/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 81/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 82/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 83/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 84/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 85/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 86/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 87/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 88/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 89/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 90/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 91/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 92/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 93/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 94/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 95/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 96/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 97/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 98/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 99/100
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 100/100
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0057 - val_mse: 0.0057
# 50/50 [==============================] - 1s 4ms/step
# 0.06340897907250957
