# %% [markdown]
# <a href="https://colab.research.google.com/github/DIPANJAN001/Dipanjanpatra/blob/master/best7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install Boruta
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from boruta import BorutaPy
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import concatenate
from keras import Model
from keras.layers import Input
from keras.layers import Bidirectional
from keras import layers
from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_classification
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.layers import LeakyReLU
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import BatchNormalization
from keras.models import load_model
from keras.layers import Input
from sklearn.decomposition import PCA
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Boruta
#   Downloading Boruta-0.3-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 3.7 MB/s
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from Boruta) (1.0.2)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from Boruta) (1.21.6)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from Boruta) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.17.1->Boruta) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.17.1->Boruta) (1.2.0)
# Installing collected packages: Boruta
# Successfully installed Boruta-0.3

# %%
def lstm_data_transform(x_data, y_data, num_steps):
    """ Changes data to the format for LSTM training 
for sliding window approach """
    # Prepare the list for the transformed data
    X, y = list(), list()
    # Loop of the entire data set
    for i in range(x_data.shape[0]):
        # compute a new (sliding window) index
        end_ix = i + num_steps
        # if index is larger than the size of the dataset, we stop
        if end_ix >= x_data.shape[0]:
            break
        # Get a sequence of data for x
        seq_X = x_data[i:end_ix]
        # Get only the last element of the sequency for y
        seq_y = y_data[end_ix]
        # Append the list with sequencies
        X.append(seq_X)
        y.append(seq_y)
    # Make final arrays
    x_array = np.array(X)
    y_array = np.array(y)
    return x_array, y_array

# %%
df=pd.read_excel("/content/pv_11.xlsx")
weather_input1=df.drop('power_normed',axis=1)
weather_input=weather_input1.drop('time_idx',axis=1)
solpow=df['power_normed']

# %%
rfc = RandomForestRegressor(random_state=1, n_estimators=1000, max_depth=5)
boruta_selector = BorutaPy(rfc, n_estimators='auto', verbose=2, random_state=1)
boruta_selector.fit(np.array(weather_input), np.array(solpow))
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	22
# Iteration: 	9 / 100
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	22
# Iteration: 	10 / 100
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	22
# Iteration: 	11 / 100
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	22
# Iteration: 	12 / 100
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	22
# Iteration: 	13 / 100
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	22
# Iteration: 	14 / 100
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	22
# Iteration: 	15 / 100
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	22
# Iteration: 	16 / 100
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	22
# Iteration: 	17 / 100
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	22
# Iteration: 	18 / 100
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	22
# Iteration: 	19 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	22
# Iteration: 	20 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	22
# Iteration: 	21 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	22
# Iteration: 	22 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	23 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	24 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	25 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	26 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	27 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	28 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	29 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	30 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	31 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	32 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	33 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	34 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	35 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	36 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	37 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	38 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	39 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	40 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	41 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	42 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	43 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	44 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	45 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	46 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	47 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	48 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	49 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	50 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	51 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	52 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	53 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	54 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	55 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	56 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	24
# Iteration: 	57 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	58 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	59 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	60 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	61 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	62 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	63 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	64 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	65 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	66 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	67 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	68 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	69 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	70 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	71 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	72 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	73 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	74 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	75 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	76 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	77 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	78 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	79 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	80 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	81 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	82 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	83 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	84 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	85 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	86 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	87 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	88 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	89 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	90 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	91 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	92 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	93 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	94 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	95 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	96 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	97 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	98 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
# Iteration: 	99 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	24
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	24
# BorutaPy(estimator=RandomForestRegressor(max_depth=5, n_estimators=141,
#                                          random_state=RandomState(MT19937) at 0x7F18FC52F7C0),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x7F18FC52F7C0, verbose=2)

# %%
X_important_train = boruta_selector.transform(np.array(weather_input))
num_steps = 3
# training set
(x_transformed_train,
 y_transformed_train) = lstm_data_transform(X_important_train,solpow , num_steps=num_steps)
assert x_transformed_train.shape[0] == y_transformed_train.shape[0]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_transformed_train,y_transformed_train,test_size=0.25, random_state=42,shuffle=False)
#X_train_,X_val,y_train_,y_val=train_test_split(X_train,y_train,test_size=0.2, random_state=42,shuffle=False)

# %%
inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))

# %%
from keras import optimizers

# %%
opt=optimizers.Adam(learning_rate=0.001)

# %%
def define_model1(hp):


  # firs
  fe1_0 = LSTM(hp.Int('input_unit11',min_value=32,max_value=256,step=8), activation='relu',return_sequences = True)(inputs1)
  fe1_1 = Dropout(hp.Float('Dropout_rate1',min_value=0.2,max_value=0.6,step=0.1))(fe1_0)
  fe1_2 = LSTM(hp.Int('input_unit111',min_value=16,max_value=128,step=4), activation='relu',return_sequences = True)(fe1_1)
  fe1_3= Dropout(hp.Float('Dropout_rate11',min_value=0.2,max_value=0.6,step=0.1))(fe1_2)
  fe1_4=LSTM(hp.Int('input_unit12',min_value=8,max_value=32,step=2), activation='relu')(fe1_3)
  out1_1=Dense(1, activation='relu')(fe1_4)



  fe2_0 = LSTM(hp.Int('input_unit21',min_value=32,max_value=256,step=8), activation='relu',return_sequences = True)(inputs1)
  fe2_1 = Dropout(hp.Float('Dropout_rate2',min_value=0.2,max_value=0.6,step=0.1))(fe2_0)
  fe2_2 = LSTM(hp.Int('input_unit112',min_value=32,max_value=128,step=4), activation='relu',return_sequences = True)(fe2_1)
  fe2_3= Dropout(hp.Float('Dropout_rate12',min_value=0.2,max_value=0.6,step=0.1))(fe2_2)
  fe2_4=LSTM(hp.Int('input_unit22',min_value=4,max_value=32,step=4), activation='relu')(fe2_3)
  out2_1=Dense(1, activation='relu')(fe2_4)

  fe3_0 = LSTM(hp.Int('input_unit31',min_value=32,max_value=256,step=8), activation='relu',return_sequences = True)(inputs1)
  fe3_1 = Dropout(hp.Float('Dropout_rate3',min_value=0.2,max_value=0.6,step=0.1))(fe3_0)
  fe3_2 = LSTM(hp.Int('input_unit113',min_value=32,max_value=128,step=4), activation='relu',return_sequences = True)(fe3_1)
  fe3_3= Dropout(hp.Float('Dropout_rate13',min_value=0.2,max_value=0.6,step=0.1))(fe3_2)
  fe3_4=LSTM(hp.Int('input_unit32',min_value=8,max_value=16,step=2), activation='relu')(fe3_3)
  out3_1=Dense(1, activation='relu')(fe3_4)
 
 

  #output = layers.average([ out1_1, out2_1, out3_1])
  merged3 = concatenate([out1_1,out2_1,out3_1], name='concat3')
  output = Dense(1, activation='relu')( merged3)
  

  model = Model(inputs=[inputs1], outputs=[output])
  model.compile(optimizer=opt,loss='mean_squared_error',metrics=['mse'])
 
  return model

# %%
# !pip install keras_tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras_tuner
#   Downloading keras_tuner-1.1.3-py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 15.0 MB/s
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (2.23.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (2.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (21.3)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (7.9.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 56.4 MB/s
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (2.6.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (5.1.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (2.0.10)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (57.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython->keras_tuner) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras_tuner) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras_tuner) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->keras_tuner) (3.0.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->keras_tuner) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->keras_tuner) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->keras_tuner) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->keras_tuner) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->keras_tuner) (1.24.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (3.19.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (1.50.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (2.14.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (0.38.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (1.3.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard->keras_tuner) (4.13.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras_tuner) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras_tuner) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras_tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner) (3.2.2)
# Installing collected packages: jedi, kt-legacy, keras-tuner
# Successfully installed jedi-0.18.2 keras-tuner-1.1.3 kt-legacy-1.0.4

# %%
import keras_tuner as kt

# %%
tuner = kt.RandomSearch(
    define_model1,
    objective='mse',
    max_trials=20,
    executions_per_trial=2
    )

# %%
tuner.search(
        x=X_train,
        y=y_train,
        epochs=50,
        batch_size=64,
        validation_data=(X_test,y_test)
)
# Out:
# Trial 11 Complete [00h 04m 57s]
# mse: 0.008506827056407928
#
# Best mse So Far: 0.007405242649838328
# Total elapsed time: 00h 56m 58s
#
# Search: Running Trial #12
#
# Value             |Best Value So Far |Hyperparameter
# 176               |208               |input_unit11
# 0.6               |0.5               |Dropout_rate1
# 116               |24                |input_unit111
# 0.3               |0.2               |Dropout_rate11
# 18                |30                |input_unit12
# 128               |208               |input_unit21
# 0.3               |0.2               |Dropout_rate2
# 104               |60                |input_unit112
# 0.5               |0.2               |Dropout_rate12
# 12                |4                 |input_unit22
# 96                |104               |input_unit31
# 0.4               |0.3               |Dropout_rate3
# 68                |96                |input_unit113
# 0.4               |0.3               |Dropout_rate13
# 14                |8                 |input_unit32
#
# Epoch 1/50
# 58/58 [==============================] - 15s 71ms/step - loss: 0.0278 - mse: 0.0278 - val_loss: 0.0214 - val_mse: 0.0214
# Epoch 2/50
# 58/58 [==============================] - 3s 49ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 3/50
# 58/58 [==============================] - 3s 48ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 4/50
# 58/58 [==============================] - 3s 47ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 5/50
# 58/58 [==============================] - 3s 48ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 6/50
# 58/58 [==============================] - 3s 47ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0171 - val_mse: 0.0171
# Epoch 7/50
# 58/58 [==============================] - 3s 48ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0162 - val_mse: 0.0162
# Epoch 8/50
# 58/58 [==============================] - 3s 50ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0156 - val_mse: 0.0156
# Epoch 9/50
# 58/58 [==============================] - 3s 48ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0151 - val_mse: 0.0151
# Epoch 10/50
# 58/58 [==============================] - 3s 51ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 11/50
# 58/58 [==============================] - 5s 92ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0159 - val_mse: 0.0159
# Epoch 12/50
# 58/58 [==============================] - 5s 91ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 13/50
# 58/58 [==============================] - 5s 79ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 14/50
# 58/58 [==============================] - 3s 49ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 15/50
# 58/58 [==============================] - 3s 49ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 16/50
# 58/58 [==============================] - 4s 69ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 17/50
# 58/58 [==============================] - 6s 97ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 18/50
# 58/58 [==============================] - 7s 113ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 19/50
# 58/58 [==============================] - 6s 96ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 20/50
# 58/58 [==============================] - 4s 63ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 21/50
# 58/58 [==============================] - 3s 48ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 22/50
# 58/58 [==============================] - 3s 54ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 23/50
# 58/58 [==============================] - 4s 77ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 24/50
# 58/58 [==============================] - 5s 78ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 25/50
# 58/58 [==============================] - 4s 73ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 26/50
# 58/58 [==============================] - 4s 69ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 27/50
# 58/58 [==============================] - 3s 47ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 28/50
# 58/58 [==============================] - 3s 48ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 29/50
# 58/58 [==============================] - 3s 47ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 30/50
# 58/58 [==============================] - 3s 46ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 31/50
# 58/58 [==============================] - 3s 47ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 32/50
# 58/58 [==============================] - 3s 48ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 33/50
# 58/58 [==============================] - 3s 60ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 34/50
# 58/58 [==============================] - 5s 89ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 35/50
# 58/58 [==============================] - 3s 47ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 36/50
# 58/58 [==============================] - 3s 47ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 37/50
# 58/58 [==============================] - 3s 56ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 38/50
# 58/58 [==============================] - 3s 55ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 39/50
# 58/58 [==============================] - 4s 72ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 40/50
# 58/58 [==============================] - 4s 75ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 41/50
# 58/58 [==============================] - 4s 63ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 42/50
# 58/58 [==============================] - 6s 104ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 43/50
# 58/58 [==============================] - 5s 87ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 44/50
# 58/58 [==============================] - 5s 93ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 45/50
# 58/58 [==============================] - 5s 85ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 46/50
# 58/58 [==============================] - 4s 69ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 47/50
# 58/58 [==============================] - 3s 48ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 48/50
# 58/58 [==============================] - 3s 47ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 49/50
# 58/58 [==============================] - 3s 46ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 50/50
# 58/58 [==============================] - 3s 47ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 1/50
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py", line 2648, in get_attr
#     pywrap_tf_session.TF_OperationGetAttrValueProto(self._c_op, name, buf)
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Operation 'gradient_tape/model/lstm_3/transpose_1/InvertPermutation' has no attr named '_read_only_resource_inputs'.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-13-ec90509a9090>", line 6, in <module>
#     validation_data=(X_test,y_test)
#   File "/usr/local/lib/python3.7/dist-packages/keras_tuner/engine/base_tuner.py", line 183, in search
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/keras_tuner/engine/tuner.py", line 295, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/keras_tuner/engine/tuner.py", line 222, in _build_and_fit_model
#     results = self.hypermodel.fit(hp, model, *args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/keras_tuner/engine/hypermodel.py", line 140, in fit
#     return model.fit(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1409, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py", line 915, in __call__
#     result = self._call(*args, **kwds)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py", line 980, in _call
#     return self._stateless_fn(*args, **kwds)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py", line 2452, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py", line 2711, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py", line 2636, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py", line 1182, in func_graph_from_py_func
#     func_graph.variables = variables
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/auto_control_deps.py", line 464, in __exit__
#     for inp, resource_type in _get_resource_inputs(op):
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/auto_control_deps.py", line 662, in _get_resource_inputs
#     reads, writes = utils.get_read_write_resource_inputs(op)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/auto_control_deps_utils.py", line 105, in get_read_write_resource_inputs
#     read_only_input_indices = op.get_attr(READ_ONLY_RESOURCE_INPUTS_ATTR)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py", line 2648, in get_attr
#     pywrap_tf_session.TF_OperationGetAttrValueProto(self._c_op, name, buf)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.7/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/usr/lib/python3.7/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/usr/lib/python3.7/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/usr/lib/python3.7/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2647       with c_api_util.tf_buffer() as buf:
# -> 2648         pywrap_tf_session.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2649         data = pywrap_tf_session.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'gradient_tape/model/lstm_3/transpose_1/InvertPermutation' has no attr named '_read_only_resource_inputs'.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, async_)
#    3325                 else:
# -> 3326                     exec(code_obj, self.user_global_ns, self.user_ns)
#    3327             finally:
#
# <ipython-input-13-ec90509a9090> in <module>
#       5         batch_size=64,
# ----> 6         validation_data=(X_test,y_test)
#       7 )
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     182             self.on_trial_begin(trial)
# --> 183             results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     184             # `results` is None indicates user updated oracle in `run_trial()`.
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/tuner.py in run_trial(self, trial, *args, **kwargs)
#     294             copied_kwargs["callbacks"] = callbacks
# --> 295             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     296
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     221         model = self._try_build(hp)
# --> 222         results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     223         tuner_utils.validate_trial_results(
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     139         """
# --> 140         return model.fit(*args, **kwargs)
#     141
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     979         # stateless function.
# --> 980         return self._stateless_fn(*args, **kwds)
#     981     else:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
# -> 2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453     return graph_function._call_flat(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    2710
# -> 2711           graph_function = self._create_graph_function(args, kwargs)
#    2712           self._function_cache.add(cache_key, cache_key_deletion_observer,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs)
#    2635             arg_names=arg_names,
# -> 2636             capture_by_value=self._capture_by_value),
#    2637         self._function_attributes,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1181
# -> 1182     func_graph.variables = variables
#    1183
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/auto_control_deps.py in __exit__(self, unused_type, unused_value, unused_traceback)
#     463       # and last_write_to_resource.
# --> 464       for inp, resource_type in _get_resource_inputs(op):
#     465         is_read = resource_type == ResourceType.READ_ONLY
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/auto_control_deps.py in _get_resource_inputs(op)
#     661   """Returns an iterable of resources touched by this `op`."""
# --> 662   reads, writes = utils.get_read_write_resource_inputs(op)
#     663   saturated = False
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/auto_control_deps_utils.py in get_read_write_resource_inputs(op)
#     104   try:
# --> 105     read_only_input_indices = op.get_attr(READ_ONLY_RESOURCE_INPUTS_ATTR)
#     106   except ValueError:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2647       with c_api_util.tf_buffer() as buf:
# -> 2648         pywrap_tf_session.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2649         data = pywrap_tf_session.TF_GetBuffer(buf)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2039                         # in the engines. This should return a list of strings.
# -> 2040                         stb = value._render_traceback_()
#    2041                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, async_)
#    3341             if result is not None:
#    3342                 result.error_in_exec = sys.exc_info()[1]
# -> 3343             self.showtraceback(running_compiled_code=True)
#    3344         else:
#    3345             outflag = False
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2041                     except Exception:
#    2042                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2043                                             value, tb, tb_offset=tb_offset)
#    2044
#    2045                     self._showtraceback(etype, value, stb)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1383         self.tb = tb
#    1384         return FormattedTB.structured_traceback(
# -> 1385             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1386
#    1387
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1286             # Verbose modes need a full traceback
#    1287             return VerboseTB.structured_traceback(
# -> 1288                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1289             )
#    1290         elif mode == 'Minimal':
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1148         exception = self.get_parts_of_chained_exception(evalue)
#    1149         if exception:
# -> 1150             formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
#    1151             etype, evalue, etb = exception
#    1152         else:
#
# TypeError: can only concatenate str (not "list") to str

# %%
best_model = tuner.get_best_models(num_models=1)[0]
y1=best_model.predict(X_test)
print(np.sqrt(mean_squared_error(y1,y_test)))
plt.scatter(y1,y_test)
plt.show()
df_2 = pd.DataFrame()
df_2['time']=[i for i in range(len(y1))]
df_2['Actual']=y_test
df_2['Predicted']=y1
import matplotlib.pyplot as plt
plt.plot(df_2['time'],df_2['Actual'])
plt.plot(df_2['time'],df_2['Predicted'])
plt.show()

# %%
best_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 2, 19)]      0           []
#
#  lstm (LSTM)                    (None, 2, 34)        7344        ['input_1[0][0]']
#
#  lstm_3 (LSTM)                  (None, 2, 42)        10416       ['input_1[0][0]']
#
#  lstm_6 (LSTM)                  (None, 2, 62)        20336       ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 2, 34)        0           ['lstm[0][0]']
#
#  dropout_2 (Dropout)            (None, 2, 42)        0           ['lstm_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 2, 62)        0           ['lstm_6[0][0]']
#
#  lstm_1 (LSTM)                  (None, 2, 46)        14904       ['dropout[0][0]']
#
#  lstm_4 (LSTM)                  (None, 2, 12)        2640        ['dropout_2[0][0]']
#
#  lstm_7 (LSTM)                  (None, 2, 40)        16480       ['dropout_4[0][0]']
#
#  dropout_1 (Dropout)            (None, 2, 46)        0           ['lstm_1[0][0]']
#
#  dropout_3 (Dropout)            (None, 2, 12)        0           ['lstm_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 2, 40)        0           ['lstm_7[0][0]']
#
#  lstm_2 (LSTM)                  (None, 18)           4680        ['dropout_1[0][0]']
#
#  lstm_5 (LSTM)                  (None, 4)            272         ['dropout_3[0][0]']
#
#  lstm_8 (LSTM)                  (None, 14)           3080        ['dropout_5[0][0]']
#
#  dense (Dense)                  (None, 1)            19          ['lstm_2[0][0]']
#
#  dense_1 (Dense)                (None, 1)            5           ['lstm_5[0][0]']
#
#  dense_2 (Dense)                (None, 1)            15          ['lstm_8[0][0]']
#
#  average (Average)              (None, 1)            0           ['dense[0][0]',
#                                                                   'dense_1[0][0]',
#                                                                   'dense_2[0][0]']
#
# ==================================================================================================
# Total params: 80,191
# Trainable params: 80,191
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
best_model = tuner.get_best_models(num_models=1)[0]
y1=best_model.predict(X_test)
print(np.sqrt(mean_squared_error(y1,y_test)))
plt.scatter(y1,y_test)
plt.show()
df_2 = pd.DataFrame()
df_2['time']=[i for i in range(len(y1))]
df_2['Actual']=y_test
df_2['Predicted']=y1
import matplotlib.pyplot as plt
plt.plot(df_2['time'],df_2['Actual'])
plt.plot(df_2['time'],df_2['Predicted'])
plt.show()
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# 77/77 [==============================] - 1s 3ms/step
# 0.06670526390350566

# %%
def define_model2(hp):


  # firs
  fe1_0 = LSTM(hp.Int('input_unit11',min_value=8,max_value=64,step=2), activation='relu',return_sequences = True)(inputs1)
  fe1_1 = Dropout(hp.Float('Dropout_rate1',min_value=0.2,max_value=0.5,step=0.1))(fe1_0)
  #fe1_2 = LSTM(16, activation='relu',return_sequences = True)(fe1_1)
  #fe1_3= Dropout(0.2)(fe1_2)
  fe1_4=LSTM(hp.Int('input_unit12',min_value=4,max_value=64,step=2), activation='relu')(fe1_1)
  out1_1=Dense(1, activation='linear')(fe1_4)



  fe2_0 = LSTM(hp.Int('input_unit21',min_value=8,max_value=64,step=2), activation='relu',return_sequences = True)(inputs1)
  fe2_1 = Dropout(hp.Float('Dropout_rate2',min_value=0.2,max_value=0.5,step=0.1))(fe2_0)
  #fe2_2 = LSTM(16, activation='relu',return_sequences = True)(fe2_1)
  #fe2_3= Dropout(0.5)(fe2_2)
  fe2_4=LSTM(hp.Int('input_unit22',min_value=4,max_value=64,step=2), activation='relu')(fe2_1)
  out2_1=Dense(1, activation='linear')(fe2_4)

  fe3_0 = LSTM(hp.Int('input_unit31',min_value=8,max_value=64,step=2), activation='relu',return_sequences = True)(inputs1)
  fe3_1 = Dropout(hp.Float('Dropout_rate3',min_value=0.2,max_value=0.5,step=0.1))(fe3_0)
  #fe3_2 = LSTM(8, activation='relu',return_sequences = True)(fe3_1)
  #fe3_3= Dropout(0.5)(fe3_2)
  fe3_4=LSTM(hp.Int('input_unit32',min_value=4,max_value=64,step=2), activation='relu')(fe3_1)
  out3_1=Dense(1, activation='linear')(fe3_4)
 
 

  merged3 = concatenate([out1_1,out2_1,out3_1], name='concat3')
  output = Dense(1, activation='linear')( merged3)
  

  model = Model(inputs=[inputs1], outputs=[output])
  model.compile(optimizer='adam',loss='mean_squared_error',metrics=['mse'])
 
  return model

# %%
tuner1 = kt.RandomSearch(
    define_model2,
    objective='mse',
    max_trials=10,
    executions_per_trial=3
    )

# %%
tuner1.search(
        x=X_train,
        y=y_train,
        epochs=75,
        batch_size=64,
        validation_data=(X_test,y_test)
)
# Out:
# Trial 2 Complete [00h 03m 57s]
# mse: 0.0034748322796076536
#
# Best mse So Far: 0.003414643850798408
# Total elapsed time: 00h 07m 20s
#
# Search: Running Trial #3
#
# Value             |Best Value So Far |Hyperparameter
# 26                |30                |input_unit11
# 0.4               |0.3               |Dropout_rate1
# 24                |16                |input_unit12
# 32                |40                |input_unit21
# 0.3               |0.3               |Dropout_rate2
# 28                |16                |input_unit22
# 24                |16                |input_unit31
# 0.4               |0.2               |Dropout_rate3
# 8                 |12                |input_unit32
#
# Epoch 1/50
# 58/58 [==============================] - 10s 34ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 2/50
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 3/50
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 4/50
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 5/50
# 31/58 [===============>..............] - ETA: 0s - loss: 0.0065 - mse: 0.0065
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-0e08c727fd3b> in <module>
#       4         epochs=50,
#       5         batch_size=64,
# ----> 6         validation_data=(X_test,y_test)
#       7 )
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     181
#     182             self.on_trial_begin(trial)
# --> 183             results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     184             # `results` is None indicates user updated oracle in `run_trial()`.
#     185             if results is None:
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/tuner.py in run_trial(self, trial, *args, **kwargs)
#     293             callbacks.append(model_checkpoint)
#     294             copied_kwargs["callbacks"] = callbacks
# --> 295             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     296
#     297             histories.append(obj_value)
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     220         hp = trial.hyperparameters
#     221         model = self._try_build(hp)
# --> 222         results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     223         tuner_utils.validate_trial_results(
#     224             results, self.oracle.objective, "HyperModel.fit()"
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     138             If return a float, it should be the `objective` value.
#     139         """
# --> 140         return model.fit(*args, **kwargs)
#     141
#     142
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453     return graph_function._call_flat(
# -> 2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#    2456   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1859       # No tape is watching; skip to running the function.
#    1860       return self._build_call_outputs(self._inference_function.call(
# -> 1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#    1863         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     500               inputs=args,
#     501               attrs=attrs,
# --> 502               ctx=ctx)
#     503         else:
#     504           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
'''def get_model11(): 
    #inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))
    fe1_0 = Bidirectional(LSTM(64, activation='relu',return_sequences = True))(inputs1)#32
    fe1_1 = Dropout(0.5)(fe1_0)
    fe1_2 = Bidirectional(LSTM(32, activation='relu',return_sequences = True))(fe1_1)#16
    fe1_3= Dropout(0.5)(fe1_2)
    fe1_4=Bidirectional(LSTM(8, activation='relu'))(fe1_3)#8
    out1_1=Dense(1, activation='linear')(fe1_4)
    return Model(inputs1, out1_1)
def get_model21(): 
    #inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))
    fe2_0 = Bidirectional(LSTM(64, activation='relu',return_sequences = True))(inputs1)#16,16,8
    fe2_1 = Dropout(0.5)(fe2_0)
    fe2_2 = Bidirectional(LSTM(32, activation='relu',return_sequences = True))(fe2_1)
    fe2_3= Dropout(0.5)(fe2_2)
    fe2_4=Bidirectional(LSTM(8, activation='relu'))(fe2_3)
    out2_1=Dense(1, activation='linear')(fe2_4)
    return Model(inputs1, out2_1)
def get_model31(): 
    #inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))
    fe3_0 = Bidirectional(LSTM(64, activation='relu',return_sequences = True))(inputs1)#16,8,8
    fe3_1 = Dropout(0.5)(fe3_0)
    fe3_2 = Bidirectional(LSTM(32, activation='relu',return_sequences = True))(fe3_1)
    fe3_3= Dropout(0.5)(fe3_2)
    fe3_4=Bidirectional(LSTM(8, activation='relu'))(fe3_3)
    out3_1=Dense(1, activation='linear')(fe3_4)
    return Model(inputs1, out3_1)
model1 = get_model11() 
model2 = get_model21() 
model3 = get_model31()
y1 = model1(inputs1) 
y2 = model2(inputs1) 
y3 = model3(inputs1)
outputs = layers.average([y1, y2, y3]) 
ensemble_model1 = Model(inputs=inputs1, outputs=outputs)
ensemble_model1.compile(optimizer='Adam',loss='mean_squared_error',metrics=['RootMeanSquaredError'])
history1=ensemble_model1.fit(X_train, y_train, epochs = 200,validation_split=0.2,batch_size = 64)
y1=ensemble_model1.predict(X_test)
print(np.sqrt(mean_squared_error(y1,y_test)))
plt.scatter(y1,y_test)
plt.show()
df_1 = pd.DataFrame()
df_1['time']=[i for i in range(len(y1))]
df_1['Actual']=y_test
df_1['Predicted']=y1
import matplotlib.pyplot as plt
plt.plot(df_1['time'],df_1['Actual'])
plt.plot(df_1['time'],df_1['Predicted'])
plt.show()
plt.plot(history1.history['loss'], label='train')
plt.plot(history1.history['val_loss'], label='val')'''

# %%
'''def get_model12(): 
    #inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))
    fe1_0 = LSTM(64, activation='relu',return_sequences = True)(inputs1)#32
    fe1_1 = Dropout(0.5)(fe1_0)
    fe1_2 = LSTM(32, activation='relu',return_sequences = True)(fe1_1)#16
    fe1_3= Dropout(0.5)(fe1_2)
    fe1_4=LSTM(8, activation='relu')(fe1_3)#8
    out1_1=Dense(1, activation='linear')(fe1_4)
    return Model(inputs1, out1_1)
def get_model22(): 
    #inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))
    fe2_0 = LSTM(64, activation='relu',return_sequences = True)(inputs1)#16,16,8
    fe2_1 = Dropout(0.5)(fe2_0)
    fe2_2 = LSTM(32, activation='relu',return_sequences = True)(fe2_1)
    fe2_3= Dropout(0.5)(fe2_2)
    fe2_4=LSTM(8, activation='relu')(fe2_3)
    out2_1=Dense(1, activation='linear')(fe2_4)
    return Model(inputs1, out2_1)
def get_model32(): 
    #inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))
    fe3_0 = LSTM(64, activation='relu',return_sequences = True)(inputs1)#16,8,8
    fe3_1 = Dropout(0.7)(fe3_0)
    fe3_2 = LSTM(32, activation='relu',return_sequences = True)(fe3_1)
    fe3_3= Dropout(0.7)(fe3_2)
    fe3_4=LSTM(8, activation='relu')(fe3_3)
    out3_1=Dense(1, activation='linear')(fe3_4)
    return Model(inputs1, out3_1)
model1 = get_model12() 
model2 = get_model22() 
model3 = get_model32()
y1 = model1(inputs1) 
y2 = model2(inputs1) 
y3 = model3(inputs1)
outputs = layers.average([y1, y2, y3]) 
ensemble_model2 = Model(inputs=inputs1, outputs=outputs)
ensemble_model2.compile(optimizer='Adam',loss='mean_squared_error',metrics=['RootMeanSquaredError'])
history2=ensemble_model2.fit(X_train, y_train, epochs = 200,validation_split=0.2,batch_size = 64)
y2=ensemble_model2.predict(X_test)
print(np.sqrt(mean_squared_error(y2,y_test)))
plt.scatter(y2,y_test)
plt.show()
df_2 = pd.DataFrame()
df_2['time']=[i for i in range(len(y2))]
df_2['Actual']=y_test
df_2['Predicted']=y2
import matplotlib.pyplot as plt
plt.plot(df_2['time'],df_2['Actual'])
plt.plot(df_2['time'],df_2['Predicted'])
plt.show()
plt.plot(history2.history['loss'], label='train')
plt.plot(history2.history['val_loss'], label='val')
plt.legend()
plt.show()'''

# %%
'''def get_model12(): 
    #inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))
    fe1_0 = LSTM(32, activation='relu',return_sequences = True)(inputs1)#32
    fe1_1 = Dropout(0.5)(fe1_0)
    fe1_2 = LSTM(16, activation='relu',return_sequences = True)(fe1_1)#16
    fe1_3= Dropout(0.5)(fe1_2)
    fe1_4=LSTM(8, activation='relu')(fe1_3)#8
    out1_1=Dense(1, activation='linear')(fe1_4)
    return Model(inputs1, out1_1)
def get_model11_(): 
    #inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))
    fe1_0 = Bidirectional(LSTM(64, activation='relu',return_sequences = True))(inputs1)#32
    fe1_1 = Dropout(0.5)(fe1_0)
    fe1_2 = Bidirectional(LSTM(32, activation='relu',return_sequences = True))(fe1_1)#16
    fe1_3= Dropout(0.5)(fe1_2)
    fe1_4=Bidirectional(LSTM(8, activation='relu'))(fe1_3)#8
    out1_1=Dense(1, activation='linear')(fe1_4)
    return Model(inputs1, out1_1)
def get_model22(): 
    #inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))
    fe2_0 = LSTM(32, activation='relu',return_sequences = True)(inputs1)#16,16,8
    fe2_1 = Dropout(0.5)(fe2_0)
    fe2_2 = LSTM(16, activation='relu',return_sequences = True)(fe2_1)
    fe2_3= Dropout(0.5)(fe2_2)
    fe2_4=LSTM(8, activation='relu')(fe2_3)
    out2_1=Dense(1, activation='linear')(fe2_4)
    return Model(inputs1, out2_1)
def get_model11(): 
    #inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))
    fe1_0 = Bidirectional(LSTM(64, activation='relu',return_sequences = True))(inputs1)#32
    fe1_1 = Dropout(0.2)(fe1_0)
    fe1_2 = Bidirectional(LSTM(32, activation='relu',return_sequences = True))(fe1_1)#16
    fe1_3= Dropout(0.2)(fe1_2)
    fe1_4=Bidirectional(LSTM(8, activation='relu'))(fe1_3)#8
    out1_1=Dense(1, activation='linear')(fe1_4)
    return Model(inputs1, out1_1)'''
'''model1 = get_model12() 
#model2 = get_model11_() 
model3 = get_model22()
#model4 = get_model11()
y1 = model1(inputs1) 
y2 = model3(inputs1) 
#y3 = model3(inputs1)
#y4 = model4(inputs1)
outputs = layers.average([y1, y2]) 
ensemble_model2 = Model(inputs=inputs1, outputs=outputs)
ensemble_model2.compile(optimizer='Adam',loss='mean_squared_error',metrics=['RootMeanSquaredError'])
history2=ensemble_model2.fit(X_train, y_train, epochs = 200,validation_split=0.2,batch_size = 64)
y2=ensemble_model2.predict(X_test)
print(np.sqrt(mean_squared_error(y2,y_test)))
plt.scatter(y2,y_test)
plt.show()
df_2 = pd.DataFrame()
df_2['time']=[i for i in range(len(y2))]
df_2['Actual']=y_test
df_2['Predicted']=y2
import matplotlib.pyplot as plt
plt.plot(df_2['time'],df_2['Actual'])
plt.plot(df_2['time'],df_2['Predicted'])
plt.show()
plt.plot(history2.history['loss'], label='train')
plt.plot(history2.history['val_loss'], label='val')
plt.legend()
plt.show()'''

# %%
'''def get_model12(): 
    #inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))
    fe1_0 = LSTM(64, activation='relu',return_sequences = True)(inputs1)#32
    fe1_1 = Dropout(0.5)(fe1_0)
    fe1_2 = LSTM(32, activation='relu',return_sequences = True)(fe1_1)#16
    fe1_3= Dropout(0.5)(fe1_2)
    fe1_4=LSTM(8, activation='relu')(fe1_3)#8
    out1_1=Dense(1, activation='linear')(fe1_4)
    return Model(inputs1, out1_1)
def get_model22(): 
    #inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))
    fe2_0 = LSTM(64, activation='relu',return_sequences = True)(inputs1)#16,16,8
    fe2_1 = Dropout(0.5)(fe2_0)
    fe2_2 = LSTM(32, activation='relu',return_sequences = True)(fe2_1)
    fe2_3= Dropout(0.5)(fe2_2)
    fe2_4=LSTM(8, activation='relu')(fe2_3)
    out2_1=Dense(1, activation='linear')(fe2_4)
    return Model(inputs1, out2_1)
def get_model32(): 
    #inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))
    fe3_0 = LSTM(64, activation='relu',return_sequences = True)(inputs1)#16,8,8
    fe3_1 = Dropout(0.7)(fe3_0)
    fe3_2 = LSTM(32, activation='relu',return_sequences = True)(fe3_1)
    fe3_3= Dropout(0.7)(fe3_2)
    fe3_4=LSTM(8, activation='relu')(fe3_3)
    out3_1=Dense(1, activation='linear')(fe3_4)
    return Model(inputs1, out3_1)
def get_model42(): 
    #inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))
    fe3_0 = LSTM(64, activation='relu',return_sequences = True)(inputs1)#16,8,8
    fe3_1 = Dropout(0.7)(fe3_0)
    fe3_2 = LSTM(32, activation='relu',return_sequences = True)(fe3_1)
    fe3_3= Dropout(0.7)(fe3_2)
    fe3_4=LSTM(8, activation='relu')(fe3_3)
    out3_1=Dense(1, activation='linear')(fe3_4)
    return Model(inputs1, out3_1)
model1 = get_model12() 
model2 = get_model22() 
model3 = get_model32()
model4 = get_model42()
y1 = model1(inputs1) 
y2 = model2(inputs1) 
y3 = model3(inputs1)
y4 = model4(inputs1)
outputs = layers.average([y1, y2, y3,y4]) 
ensemble_model2 = Model(inputs=inputs1, outputs=outputs)
ensemble_model2.compile(optimizer='Adam',loss='mean_squared_error',metrics=['RootMeanSquaredError'])
history2=ensemble_model2.fit(X_train, y_train, epochs = 200,validation_split=0.2,batch_size = 64)
y2=ensemble_model2.predict(X_test)
print(np.sqrt(mean_squared_error(y2,y_test)))
plt.scatter(y2,y_test)
plt.show()
df_2 = pd.DataFrame()
df_2['time']=[i for i in range(len(y2))]
df_2['Actual']=y_test
df_2['Predicted']=y2
import matplotlib.pyplot as plt
plt.plot(df_2['time'],df_2['Actual'])
plt.plot(df_2['time'],df_2['Predicted'])
plt.show()
plt.plot(history2.history['loss'], label='train')
plt.plot(history2.history['val_loss'], label='val')
plt.legend()
plt.show()'''

# %%
opt=optimizers.Adam(learning_rate=0.001)

# %%
def define_model_():


  # firs
  fe1_0 = LSTM(208, activation='tanh',return_sequences = True)(inputs1)
  fe1_1 = Dropout(0.5)(fe1_0)
  fe1_2 = LSTM(24, activation='relu',return_sequences = True)(fe1_1)
  fe1_3= Dropout(0.2)(fe1_2)
  fe1_4=LSTM(30, activation='tanh')(fe1_3)
  out1_1=Dense(1, activation='relu')(fe1_4)



  fe2_0 = LSTM(208, activation='tanh',return_sequences = True)(inputs1)
  fe2_1 = Dropout(0.2)(fe2_0)
  fe2_2 = LSTM(60, activation='relu',return_sequences = True)(fe2_1)
  fe2_3= Dropout(0.2)(fe2_2)
  fe2_4=LSTM(4, activation='tanh')(fe2_3)
  out2_1=Dense(1, activation='relu')(fe2_4)

  fe3_0 =LSTM(104, activation='tanh',return_sequences = True)(inputs1)
  fe3_1 = Dropout(0.6)(fe3_0)
  fe3_2 = LSTM(96, activation='relu',return_sequences = True)(fe3_1)
  fe3_3= Dropout(0.5)(fe3_2)
  fe3_4=LSTM(8, activation='tanh')(fe3_3)#16
  out3_1=Dense(1, activation='relu')(fe3_4)
 
 

  output = layers.average([ out1_1, out2_1, out3_1])
  #merged3 = concatenate([out1_1,out2_1,out3_1], name='concat3')
  #output = Dense(1, activation='tanh')( merged3)
  

  model = Model(inputs=[inputs1], outputs=[output])
  model.compile(optimizer=opt,loss='mean_squared_error',metrics=['mse'])
 
  return model
mdl=define_model_()
history=mdl.fit(X_train, y_train, epochs = 500,validation_split=0.2,batch_size = 64)
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='')
plt.legend()
plt.show()
y=mdl.predict(X_test)
plt.scatter(y,y_test)
plt.show()
df = pd.DataFrame()
df['time']=[i for i in range(len(y))]
df['Actual']=y_test
df['Predicted']=y
plt.plot(df['time'],df['Actual'])
plt.plot(df['time'],df['Predicted'])
plt.show()
# Out:
# Epoch 1/500
# 47/47 [==============================] - 32s 109ms/step - loss: 0.0322 - mse: 0.0322 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 2/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 3/500
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 4/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 5/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 6/500
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 7/500
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 8/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 9/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 10/500
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 11/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 12/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 13/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 14/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 15/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 16/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 17/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 18/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 19/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 20/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 21/500
# 47/47 [==============================] - 3s 56ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 22/500
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 23/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 24/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 25/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 26/500
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 27/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 28/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 29/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 30/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 31/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 32/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 33/500
# 47/47 [==============================] - 3s 55ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 34/500
# 47/47 [==============================] - 3s 65ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 35/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 36/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 37/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 38/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 39/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 40/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 41/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 42/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 43/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 44/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 45/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 46/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 47/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 48/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 49/500
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 50/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 51/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 52/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 53/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 54/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 55/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 56/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 57/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 58/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 59/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 60/500
# 47/47 [==============================] - 3s 58ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 61/500
# 47/47 [==============================] - 4s 77ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 62/500
# 47/47 [==============================] - 4s 95ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 63/500
# 47/47 [==============================] - 5s 101ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 64/500
# 47/47 [==============================] - 4s 86ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 65/500
# 47/47 [==============================] - 4s 75ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 66/500
# 47/47 [==============================] - 4s 82ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 67/500
# 47/47 [==============================] - 4s 87ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 68/500
# 47/47 [==============================] - 4s 93ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 69/500
# 47/47 [==============================] - 4s 83ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 70/500
# 47/47 [==============================] - 3s 59ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 71/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 72/500
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 73/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 74/500
# 47/47 [==============================] - 3s 64ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 75/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 76/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 77/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 78/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 79/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 80/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 81/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 82/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 83/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 84/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 85/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 86/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 87/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 88/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 89/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 90/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 91/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 92/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 93/500
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 94/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 95/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 96/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 97/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 98/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 99/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 100/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 101/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 102/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 103/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 104/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 105/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 106/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 107/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 108/500
# 47/47 [==============================] - 2s 51ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 109/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 110/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 111/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 112/500
# 47/47 [==============================] - 3s 64ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 113/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 114/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 115/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 116/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 117/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 118/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 119/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 120/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 121/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 122/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 123/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 124/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 125/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 126/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 127/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 128/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 129/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 130/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 131/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 132/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 133/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 134/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 135/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 136/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 137/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 138/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 139/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 140/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 141/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 142/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 143/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 144/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 145/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 146/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 147/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 148/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 149/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 150/500
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 151/500
# 47/47 [==============================] - 3s 55ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 152/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 153/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 154/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 155/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 156/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 157/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 158/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 159/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 160/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 161/500
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 162/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 163/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 164/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 165/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 166/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 167/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 168/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 169/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 170/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 171/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 172/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 173/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 174/500
# 47/47 [==============================] - 3s 66ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 175/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 176/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 177/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 178/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 179/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 180/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 181/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 182/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 183/500
# 47/47 [==============================] - 4s 75ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 184/500
# 47/47 [==============================] - 3s 56ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 185/500
# 47/47 [==============================] - 3s 62ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 186/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 187/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 188/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 189/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 190/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 191/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 192/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 193/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 194/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 195/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 196/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 197/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 198/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 199/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 200/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 201/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 202/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 203/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 204/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 205/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 206/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 207/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 208/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 209/500
# 47/47 [==============================] - 3s 66ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 210/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 211/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 212/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 213/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 214/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 215/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 216/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 217/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 218/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 219/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 220/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 221/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 222/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 223/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 224/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 225/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 226/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 227/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 228/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 229/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 230/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 231/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 232/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 233/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 234/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 235/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 236/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 237/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 238/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 239/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 240/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 241/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 242/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 243/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 244/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 245/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 246/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 247/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 248/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 249/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 250/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 251/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 252/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 253/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 254/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 255/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 256/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 257/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 258/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 259/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 260/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 261/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 262/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 263/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 264/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 265/500
# 47/47 [==============================] - 3s 59ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 266/500
# 47/47 [==============================] - 3s 71ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 267/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 268/500
# 47/47 [==============================] - 2s 53ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 269/500
# 47/47 [==============================] - 3s 61ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 270/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 271/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 272/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 273/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 274/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 275/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 276/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 277/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 278/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 279/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 280/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 281/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 282/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 283/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 284/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 285/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 286/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 287/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 288/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 289/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 290/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 291/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 292/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 293/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 294/500
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 295/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 296/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 297/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 298/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 299/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 300/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 301/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 302/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 303/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 304/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 305/500
# 47/47 [==============================] - 3s 67ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 306/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 307/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 308/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 309/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 310/500
# 47/47 [==============================] - 2s 51ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 311/500
# 47/47 [==============================] - 4s 90ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 312/500
# 47/47 [==============================] - 4s 78ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 313/500
# 47/47 [==============================] - 3s 67ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 314/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 315/500
# 47/47 [==============================] - 3s 72ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 316/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 317/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 318/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 319/500
# 47/47 [==============================] - 3s 64ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 320/500
# 47/47 [==============================] - 3s 55ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 321/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 322/500
# 47/47 [==============================] - 3s 68ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 323/500
# 47/47 [==============================] - 4s 90ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 324/500
# 47/47 [==============================] - 4s 89ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 325/500
# 47/47 [==============================] - 3s 73ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 326/500
# 47/47 [==============================] - 3s 62ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 327/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 328/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 329/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 330/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 331/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 332/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 333/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 334/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 335/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 336/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 337/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 338/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 339/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 340/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 341/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 342/500
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 343/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 344/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 345/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 346/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 347/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 348/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 349/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 350/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 351/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 352/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 353/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 354/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 355/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 356/500
# 47/47 [==============================] - 3s 59ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 357/500
# 47/47 [==============================] - 3s 68ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 358/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 359/500
# ...
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 383/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 384/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 385/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 386/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 387/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 388/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 389/500
# 47/47 [==============================] - 3s 66ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 390/500
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 391/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 392/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 393/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 394/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 395/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 396/500
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 397/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 398/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 399/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 400/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 401/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 402/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 403/500
# 47/47 [==============================] - 2s 51ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 404/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 405/500
# 47/47 [==============================] - 3s 67ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 406/500
# 47/47 [==============================] - 3s 57ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 407/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 408/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 409/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 410/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 411/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 412/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 413/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 414/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 415/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 416/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 417/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 418/500
# 47/47 [==============================] - 3s 61ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 419/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 420/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 421/500
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 422/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 423/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 424/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 425/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 426/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 427/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 428/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 429/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 430/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 431/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 432/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 433/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 434/500
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 435/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 436/500
# 47/47 [==============================] - 3s 57ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 437/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 438/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 439/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 440/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 441/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 442/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 443/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 444/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 445/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 446/500
# 47/47 [==============================] - 2s 53ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 447/500
# 47/47 [==============================] - 3s 61ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 448/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 449/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 450/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 451/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 452/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 453/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 454/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 455/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 456/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 457/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 458/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 459/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 460/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 461/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 462/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 463/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 464/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 465/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 466/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 467/500
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 468/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 469/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 470/500
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 471/500
# 47/47 [==============================] - 2s 53ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 472/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 473/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 474/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 475/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 476/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 477/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 478/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 479/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 480/500
# 47/47 [==============================] - 3s 68ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 481/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 482/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 483/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 484/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 485/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 486/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 487/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 488/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 489/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 490/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 491/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 492/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 493/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 494/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 495/500
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 496/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 497/500
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 498/500
# 47/47 [==============================] - 2s 49ms/step - loss: 9.3336e-04 - mse: 9.3336e-04 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 499/500
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 500/500
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0054 - val_mse: 0.0054
# 77/77 [==============================] - 3s 9ms/step

# %%
print(np.sqrt(mean_squared_error(y,y_test)))
# Out:
# 0.13431422448066643

# %%
def define_model():


  # firs
  fe1_0 = LSTM(208, activation='relu',return_sequences = True)(inputs1)
  fe1_1 = Dropout(0.5)(fe1_0)
  fe1_2 = LSTM(24, activation='relu',return_sequences = True)(fe1_1)
  fe1_3= Dropout(0.3)(fe1_2)
  fe1_4=LSTM(30, activation='relu')(fe1_3)
  out1_1=Dense(1, activation='relu')(fe1_4)



  fe2_0 = LSTM(208, activation='relu',return_sequences = True)(inputs1)
  fe2_1 = Dropout(0.4)(fe2_0)
  fe2_2 = LSTM(60, activation='relu',return_sequences = True)(fe2_1)
  fe2_3= Dropout(0.4)(fe2_2)
  fe2_4=LSTM(4, activation='relu')(fe2_3)
  out2_1=Dense(1, activation='relu')(fe2_4)

  fe3_0 =LSTM(104, activation='relu',return_sequences = True)(inputs1)
  fe3_1 = Dropout(0.6)(fe3_0)
  fe3_2 = LSTM(96, activation='relu',return_sequences = True)(fe3_1)
  fe3_3= Dropout(0.5)(fe3_2)
  fe3_4=LSTM(8, activation='relu')(fe3_3)#16
  out3_1=Dense(1, activation='relu')(fe3_4)
 
 

  output = layers.average([ out1_1, out2_1, out3_1])
  #merged3 = concatenate([out1_1,out2_1,out3_1], name='concat3')
  #output = Dense(1, activation='tanh')( merged3)
  

  model = Model(inputs=[inputs1], outputs=[output])
  model.compile(optimizer=opt,loss='mean_squared_error',metrics=['mse'])
 
  return model
mdl=define_model()
history=mdl.fit(X_train, y_train, epochs = 100,validation_split=0.2,batch_size = 64)
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='')
plt.legend()
plt.show()
y=mdl.predict(X_test)
plt.scatter(y,y_test)
plt.show()
df = pd.DataFrame()
df['time']=[i for i in range(len(y))]
df['Actual']=y_test
df['Predicted']=y
plt.plot(df['time'],df['Actual'])
plt.plot(df['time'],df['Predicted'])
plt.show()
print(np.sqrt(mean_squared_error(y,y_test)))
# Out:
# Epoch 1/100
# 47/47 [==============================] - 16s 75ms/step - loss: 0.0338 - mse: 0.0338 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 2/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 3/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 4/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 5/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 6/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 7/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 8/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 9/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 10/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 11/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 12/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 13/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 14/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 15/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 16/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 17/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 18/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 19/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 20/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 21/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 22/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 23/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 24/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 25/100
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 26/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 27/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 28/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 29/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 30/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 31/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 32/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 33/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 34/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 35/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 36/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 37/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 38/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 39/100
# 47/47 [==============================] - 3s 63ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 40/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 41/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 42/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 43/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 44/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 45/100
# 47/47 [==============================] - 3s 54ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 46/100
# 47/47 [==============================] - 3s 64ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 47/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 48/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 49/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 50/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 51/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 52/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 53/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 54/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 55/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 56/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 57/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 58/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 59/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 60/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 61/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 62/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 63/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 64/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 65/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 66/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 67/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 68/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 69/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 70/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 71/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 72/100
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 73/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 74/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 75/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 76/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 77/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 78/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 79/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 80/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 81/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 82/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 83/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 84/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 85/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 86/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 87/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 88/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 89/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 90/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 91/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 92/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 93/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 94/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 95/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 96/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 97/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 98/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 99/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 100/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0047 - val_mse: 0.0047
# 77/77 [==============================] - 2s 9ms/step
# 0.11437901668553925

# %%
def define_model():


  # firs
  fe1_0 = LSTM(208, activation='relu',return_sequences = True)(inputs1)
  fe1_1 = Dropout(0.5)(fe1_0)
  fe1_2 = LSTM(24, activation='relu',return_sequences = True)(fe1_1)
  fe1_3= Dropout(0.2)(fe1_2)
  fe1_4=LSTM(30, activation='relu')(fe1_3)
  out1_1=Dense(1, activation='relu')(fe1_4)



  fe2_0 = LSTM(208, activation='relu',return_sequences = True)(inputs1)
  fe2_1 = Dropout(0.2)(fe2_0)
  fe2_2 = LSTM(60, activation='relu',return_sequences = True)(fe2_1)
  fe2_3= Dropout(0.2)(fe2_2)
  fe2_4=LSTM(4, activation='relu')(fe2_3)
  out2_1=Dense(1, activation='relu')(fe2_4)

  fe3_0 =LSTM(104, activation='relu',return_sequences = True)(inputs1)
  fe3_1 = Dropout(0.6)(fe3_0)
  fe3_2 = LSTM(96, activation='relu',return_sequences = True)(fe3_1)
  fe3_3= Dropout(0.5)(fe3_2)
  fe3_4=LSTM(8, activation='relu')(fe3_3)#16
  out3_1=Dense(1, activation='relu')(fe3_4)
 
 

  #output = layers.average([ out1_1, out2_1, out3_1])
  merged3 = concatenate([out1_1,out2_1,out3_1], name='concat3')
  output = Dense(1, activation='tanh')( merged3)
  

  model = Model(inputs=[inputs1], outputs=[output])
  model.compile(optimizer=opt,loss='mean_squared_error',metrics=['mse'])
 
  return model
mdl=define_model()
history=mdl.fit(X_train, y_train, epochs = 100,validation_split=0.2,batch_size = 64)
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='')
plt.legend()
plt.show()
y=mdl.predict(X_test)
plt.scatter(y,y_test)
plt.show()
df = pd.DataFrame()
df['time']=[i for i in range(len(y))]
df['Actual']=y_test
df['Predicted']=y
plt.plot(df['time'],df['Actual'])
plt.plot(df['time'],df['Predicted'])
plt.show()
print(np.sqrt(mean_squared_error(y,y_test)))
# Out:
# Epoch 1/100
# 47/47 [==============================] - 14s 71ms/step - loss: 0.0272 - mse: 0.0272 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 2/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 3/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 4/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 5/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 6/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 7/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 8/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 9/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 10/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 11/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 12/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 13/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 14/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 15/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 16/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 17/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 18/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 19/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 20/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 21/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 22/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 23/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 24/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 25/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 26/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 27/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 28/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 29/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 30/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 31/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 32/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 33/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 34/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 35/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 36/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 37/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 38/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 39/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 40/100
# 47/47 [==============================] - 2s 41ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 41/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 42/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 43/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 44/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 45/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 46/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 47/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 48/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 49/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 50/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 51/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 52/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 53/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 54/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 55/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 56/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 57/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 58/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 59/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 60/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 61/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 62/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 63/100
# 47/47 [==============================] - 3s 64ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 64/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 65/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 66/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 67/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 68/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 69/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 70/100
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 71/100
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 72/100
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 73/100
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 74/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 75/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 76/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 77/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 78/100
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 79/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 80/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 81/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 82/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 83/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 84/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 85/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 86/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 87/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 88/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 89/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 90/100
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 91/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 92/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 93/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 94/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 95/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 96/100
# 47/47 [==============================] - 3s 61ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 97/100
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 98/100
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 99/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 100/100
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0054 - val_mse: 0.0054
# 77/77 [==============================] - 2s 9ms/step
# 0.12085893023094076
