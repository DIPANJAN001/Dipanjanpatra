# %% [markdown]
# <a href="https://colab.research.google.com/github/DIPANJAN001/Dipanjanpatra/blob/master/FinalRLEnvironment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import gym
from gym.utils import seeding
from gym.spaces import Space, Discrete, MultiDiscrete,  Box
from gym.spaces.space import Space
import numpy as np

# %%
class MyEnv3(gym.Env):
    
      def __init__(self):
        
        self.action_space = Discrete(4)
        self.observation_space=Box(low=np.array([0]),high=np.array([50]),dtype=np.float32) 
        #self.battery_efficiency=0.3
        self.battery_cap=30
        self.max_battery_discharge=15
        self.max_battery_charge=10
        self.max_battery_capacity=50
        #self.reward, self.done, self.info= None, None, None
        #self.grid_import=0
        #self.grid_export=0
        self.info=None
      def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

      def _step(self,action):
        grid_import_=0
        grid_export_=0
        done=False
        load=np.random.randint(100,150)
        pv=np.random.randint(80,130)
        battery_state=self.battery_cap
        #net_load=max((load-power),0)
        #net_rem=max(net_load-(self.battery_efficiency*self.battery_cap),0)
        info={}
        reward=0
        #battery_chng=0
        
        if action== 0:
          grid_export_= max(pv-load-self.max_battery_charge,0) # grid export
          self.battery_cap= max(min(self.battery_cap+min(self.max_battery_charge,pv-load),50),0)
          grid_import_=0
          info={
              'grid_export':grid_export_,
              'grid_import':grid_import_
          }
        if action== 1:
          grid_export_= max(pv-load-self.max_battery_charge,0) # grid export
          self.battery_cap= max(min(self.battery_cap+min(self.max_battery_charge,pv-load),50),0)
          grid_import_=0
          # only battery charge
          info={
              'grid_export':grid_export_,
              'grid_import':grid_import_
          }
        if action== 2:
            grid_export_=0
            self.battery_cap= min(max(self.battery_cap-self.max_battery_discharge,0),50)# battery discharge
            grid_import_=max(load-pv-self.max_battery_discharge,0)
            info={
              'grid_export':grid_export_,
              'grid_import':grid_import_
             }
        if action== 3:
          grid_export_=0
          self.battery_cap= min(max(self.battery_cap-min(self.max_battery_discharge,load-pv),0),50)#change in battery
          grid_import_=max(load-pv-self.max_battery_discharge,0)
         #only battery discharge
          info={
              'grid_export':grid_export_,
              'grid_import':grid_import_
                    }     
        
        reward=grid_export_*8-grid_import_*10
        
        if(self.battery_cap<7.0):
              done=True
      
        return battery_state,self.battery_cap,load,pv,reward, done,info
        
      def _reset(self):
        self.battery_cap=30
        #self.done=False
        return self.battery_cap

# %%
env=MyEnv3()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
for e in range(400): #Episode
    #Play 20 episodes 
    score = 0
    observation = env._reset()
    #print(observation)
    done=False
    while not done:
        #env.render()
        action = env.action_space.sample()
        print(action)
        observation1,observation2,observation3,observation4,reward,done,info = env._step(action)
        print(observation1,observation2,observation3,observation4)
        print(info)
        score+=round(reward)
        
        #print(info['load'],info['power'])
      
    print('episode:{} Profit:{}'.format(e,score))
# Out:
# 0
# 30 0 143 113
# {'grid_export': 0, 'grid_import': 0}
# episode:0 Profit:0
# 1
# 30 0 148 99
# {'grid_export': 0, 'grid_import': 0}
# episode:1 Profit:0
# 1
# 30 37 119 126
# {'grid_export': 0, 'grid_import': 0}
# 2
# 37 22 119 88
# {'grid_export': 0, 'grid_import': 16}
# 0
# 22 0 122 98
# {'grid_export': 0, 'grid_import': 0}
# episode:2 Profit:-160
# 0
# 30 21 110 101
# {'grid_export': 0, 'grid_import': 0}
# 2
# 21 6 129 110
# {'grid_export': 0, 'grid_import': 4}
# episode:3 Profit:-40
# 0
# 30 5 139 114
# {'grid_export': 0, 'grid_import': 0}
# episode:4 Profit:0
# 1
# 30 0 120 82
# {'grid_export': 0, 'grid_import': 0}
# episode:5 Profit:0
# 3
# 30 33 104 107
# {'grid_export': 0, 'grid_import': 0}
# 3
# 33 18 121 91
# {'grid_export': 0, 'grid_import': 15}
# 3
# 18 3 140 88
# {'grid_export': 0, 'grid_import': 37}
# episode:6 Profit:-520
# 3
# 30 15 136 114
# {'grid_export': 0, 'grid_import': 7}
# 1
# 15 4 131 120
# {'grid_export': 0, 'grid_import': 0}
# episode:7 Profit:-70
# 1
# 30 2 124 96
# {'grid_export': 0, 'grid_import': 0}
# episode:8 Profit:0
# 2
# 30 15 108 113
# {'grid_export': 0, 'grid_import': 0}
# 0
# 15 0 136 112
# {'grid_export': 0, 'grid_import': 0}
# episode:9 Profit:0
# 1
# 30 3 129 102
# {'grid_export': 0, 'grid_import': 0}
# episode:10 Profit:0
# 2
# 30 15 113 128
# {'grid_export': 0, 'grid_import': 0}
# 0
# 15 4 136 125
# {'grid_export': 0, 'grid_import': 0}
# episode:11 Profit:0
# 2
# 30 15 102 80
# {'grid_export': 0, 'grid_import': 7}
# 0
# 15 0 130 88
# {'grid_export': 0, 'grid_import': 0}
# episode:12 Profit:-70
# 3
# 30 43 115 128
# {'grid_export': 0, 'grid_import': 0}
# 3
# 43 28 137 105
# {'grid_export': 0, 'grid_import': 17}
# 0
# 28 0 130 92
# {'grid_export': 0, 'grid_import': 0}
# episode:13 Profit:-170
# 2
# 30 15 118 104
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 0 132 112
# {'grid_export': 0, 'grid_import': 0}
# episode:14 Profit:0
# 0
# 30 2 118 90
# {'grid_export': 0, 'grid_import': 0}
# episode:15 Profit:0
# 0
# 30 24 104 98
# {'grid_export': 0, 'grid_import': 0}
# 2
# 24 9 140 115
# {'grid_export': 0, 'grid_import': 10}
# 1
# 9 5 127 123
# {'grid_export': 0, 'grid_import': 0}
# episode:16 Profit:-100
# 1
# 30 7 135 112
# {'grid_export': 0, 'grid_import': 0}
# 0
# 7 0 141 101
# {'grid_export': 0, 'grid_import': 0}
# episode:17 Profit:0
# 1
# 30 38 100 108
# {'grid_export': 0, 'grid_import': 0}
# 2
# 38 23 113 123
# {'grid_export': 0, 'grid_import': 0}
# 3
# 23 8 142 112
# {'grid_export': 0, 'grid_import': 15}
# 3
# 8 22 105 119
# {'grid_export': 0, 'grid_import': 0}
# 1
# 22 25 122 125
# {'grid_export': 0, 'grid_import': 0}
# 0
# 25 0 141 93
# {'grid_export': 0, 'grid_import': 0}
# episode:18 Profit:-150
# 1
# 30 20 101 91
# {'grid_export': 0, 'grid_import': 0}
# 3
# 20 11 123 114
# {'grid_export': 0, 'grid_import': 0}
# 0
# 11 8 125 122
# {'grid_export': 0, 'grid_import': 0}
# 3
# 8 0 148 97
# {'grid_export': 0, 'grid_import': 36}
# episode:19 Profit:-360
# 1
# 30 0 120 80
# {'grid_export': 0, 'grid_import': 0}
# episode:20 Profit:0
# 0
# 30 17 112 99
# {'grid_export': 0, 'grid_import': 0}
# 0
# 17 27 101 126
# {'grid_export': 15, 'grid_import': 0}
# 0
# 27 7 127 107
# {'grid_export': 0, 'grid_import': 0}
# 1
# 7 0 140 103
# {'grid_export': 0, 'grid_import': 0}
# episode:21 Profit:120
# 0
# 30 3 128 101
# {'grid_export': 0, 'grid_import': 0}
# episode:22 Profit:0
# 1
# 30 0 141 86
# {'grid_export': 0, 'grid_import': 0}
# episode:23 Profit:0
# 3
# 30 17 106 93
# {'grid_export': 0, 'grid_import': 0}
# 2
# 17 2 113 127
# {'grid_export': 0, 'grid_import': 0}
# episode:24 Profit:0
# 2
# 30 15 102 111
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 0 122 88
# {'grid_export': 0, 'grid_import': 0}
# episode:25 Profit:0
# 0
# 30 23 123 116
# {'grid_export': 0, 'grid_import': 0}
# 2
# 23 8 133 124
# {'grid_export': 0, 'grid_import': 0}
# 0
# 8 0 140 114
# {'grid_export': 0, 'grid_import': 0}
# episode:26 Profit:0
# 2
# 30 15 147 90
# {'grid_export': 0, 'grid_import': 42}
# 3
# 15 4 109 98
# {'grid_export': 0, 'grid_import': 0}
# episode:27 Profit:-420
# 1
# 30 11 138 119
# {'grid_export': 0, 'grid_import': 0}
# 0
# 11 0 113 102
# {'grid_export': 0, 'grid_import': 0}
# episode:28 Profit:0
# 0
# 30 11 131 112
# {'grid_export': 0, 'grid_import': 0}
# 0
# 11 21 104 126
# {'grid_export': 12, 'grid_import': 0}
# 0
# 21 14 116 109
# {'grid_export': 0, 'grid_import': 0}
# 0
# 14 0 136 116
# {'grid_export': 0, 'grid_import': 0}
# episode:29 Profit:96
# 0
# 30 0 137 97
# {'grid_export': 0, 'grid_import': 0}
# episode:30 Profit:0
# 3
# 30 15 131 88
# {'grid_export': 0, 'grid_import': 28}
# 2
# 15 0 127 129
# {'grid_export': 0, 'grid_import': 0}
# episode:31 Profit:-280
# 1
# 30 0 142 91
# {'grid_export': 0, 'grid_import': 0}
# episode:32 Profit:0
# 2
# 30 15 119 96
# {'grid_export': 0, 'grid_import': 8}
# 0
# 15 11 100 96
# {'grid_export': 0, 'grid_import': 0}
# 2
# 11 0 131 89
# {'grid_export': 0, 'grid_import': 27}
# episode:33 Profit:-350
# 1
# 30 0 143 95
# {'grid_export': 0, 'grid_import': 0}
# episode:34 Profit:0
# 0
# 30 9 123 102
# {'grid_export': 0, 'grid_import': 0}
# 2
# 9 0 101 110
# {'grid_export': 0, 'grid_import': 0}
# episode:35 Profit:0
# 2
# 30 15 141 96
# {'grid_export': 0, 'grid_import': 30}
# 1
# 15 0 144 121
# {'grid_export': 0, 'grid_import': 0}
# episode:36 Profit:-300
# 0
# 30 14 113 97
# {'grid_export': 0, 'grid_import': 0}
# 1
# 14 0 140 92
# {'grid_export': 0, 'grid_import': 0}
# episode:37 Profit:0
# 0
# 30 0 142 103
# {'grid_export': 0, 'grid_import': 0}
# episode:38 Profit:0
# 1
# 30 0 124 90
# {'grid_export': 0, 'grid_import': 0}
# episode:39 Profit:0
# 0
# 30 15 102 87
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 7 112 104
# {'grid_export': 0, 'grid_import': 0}
# 0
# 7 17 103 127
# {'grid_export': 14, 'grid_import': 0}
# 1
# 17 0 123 100
# {'grid_export': 0, 'grid_import': 0}
# episode:40 Profit:112
# 2
# 30 15 128 117
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 0 146 112
# {'grid_export': 0, 'grid_import': 0}
# episode:41 Profit:0
# 1
# 30 32 108 110
# {'grid_export': 0, 'grid_import': 0}
# 1
# 32 27 118 113
# {'grid_export': 0, 'grid_import': 0}
# 2
# 27 12 149 86
# {'grid_export': 0, 'grid_import': 48}
# 3
# 12 9 109 106
# {'grid_export': 0, 'grid_import': 0}
# 1
# 9 13 121 125
# {'grid_export': 0, 'grid_import': 0}
# 2
# 13 0 139 102
# {'grid_export': 0, 'grid_import': 22}
# episode:42 Profit:-700
# 1
# 30 0 140 90
# {'grid_export': 0, 'grid_import': 0}
# episode:43 Profit:0
# 0
# 30 4 134 108
# {'grid_export': 0, 'grid_import': 0}
# episode:44 Profit:0
# 3
# 30 50 107 127
# {'grid_export': 0, 'grid_import': 0}
# 1
# 50 8 129 87
# {'grid_export': 0, 'grid_import': 0}
# 1
# 8 0 144 93
# {'grid_export': 0, 'grid_import': 0}
# episode:45 Profit:0
# 2
# 30 15 110 101
# {'grid_export': 0, 'grid_import': 0}
# 3
# 15 6 113 104
# {'grid_export': 0, 'grid_import': 0}
# episode:46 Profit:0
# 3
# 30 31 107 108
# {'grid_export': 0, 'grid_import': 0}
# 0
# 31 0 137 80
# {'grid_export': 0, 'grid_import': 0}
# episode:47 Profit:0
# 0
# 30 0 136 103
# {'grid_export': 0, 'grid_import': 0}
# episode:48 Profit:0
# 3
# 30 15 141 95
# {'grid_export': 0, 'grid_import': 31}
# 0
# 15 0 142 92
# {'grid_export': 0, 'grid_import': 0}
# episode:49 Profit:-310
# 0
# 30 14 111 95
# {'grid_export': 0, 'grid_import': 0}
# 1
# 14 0 143 90
# {'grid_export': 0, 'grid_import': 0}
# episode:50 Profit:0
# 3
# 30 15 134 93
# {'grid_export': 0, 'grid_import': 26}
# 2
# 15 0 123 97
# {'grid_export': 0, 'grid_import': 11}
# episode:51 Profit:-370
# 3
# 30 38 112 120
# {'grid_export': 0, 'grid_import': 0}
# 0
# 38 12 146 120
# {'grid_export': 0, 'grid_import': 0}
# 2
# 12 0 118 82
# {'grid_export': 0, 'grid_import': 21}
# episode:52 Profit:-210
# 3
# 30 15 148 109
# {'grid_export': 0, 'grid_import': 24}
# 3
# 15 13 111 109
# {'grid_export': 0, 'grid_import': 0}
# 1
# 13 0 118 101
# {'grid_export': 0, 'grid_import': 0}
# episode:53 Profit:-240
# 2
# 30 15 107 120
# {'grid_export': 0, 'grid_import': 0}
# 0
# 15 2 140 127
# {'grid_export': 0, 'grid_import': 0}
# episode:54 Profit:0
# 3
# 30 15 114 90
# {'grid_export': 0, 'grid_import': 9}
# 2
# 15 0 149 118
# {'grid_export': 0, 'grid_import': 16}
# episode:55 Profit:-250
# 3
# 30 45 110 125
# {'grid_export': 0, 'grid_import': 0}
# 0
# 45 50 105 127
# {'grid_export': 12, 'grid_import': 0}
# 1
# 50 24 114 88
# {'grid_export': 0, 'grid_import': 0}
# 3
# 24 9 107 92
# {'grid_export': 0, 'grid_import': 0}
# 1
# 9 0 124 107
# {'grid_export': 0, 'grid_import': 0}
# episode:56 Profit:96
# 3
# 30 17 101 88
# {'grid_export': 0, 'grid_import': 0}
# 3
# 17 2 102 80
# {'grid_export': 0, 'grid_import': 7}
# episode:57 Profit:-70
# 2
# 30 15 128 97
# {'grid_export': 0, 'grid_import': 16}
# 2
# 15 0 142 111
# {'grid_export': 0, 'grid_import': 16}
# episode:58 Profit:-320
# 0
# 30 24 128 122
# {'grid_export': 0, 'grid_import': 0}
# 3
# 24 16 125 117
# {'grid_export': 0, 'grid_import': 0}
# 0
# 16 18 117 119
# {'grid_export': 0, 'grid_import': 0}
# 2
# 18 3 146 94
# {'grid_export': 0, 'grid_import': 37}
# episode:59 Profit:-370
# 1
# 30 0 145 99
# {'grid_export': 0, 'grid_import': 0}
# episode:60 Profit:0
# 1
# 30 0 142 86
# {'grid_export': 0, 'grid_import': 0}
# episode:61 Profit:0
# 3
# 30 15 137 92
# {'grid_export': 0, 'grid_import': 30}
# 3
# 15 0 138 111
# {'grid_export': 0, 'grid_import': 12}
# episode:62 Profit:-420
# 3
# 30 38 106 114
# {'grid_export': 0, 'grid_import': 0}
# 2
# 38 23 116 115
# {'grid_export': 0, 'grid_import': 0}
# 1
# 23 26 115 118
# {'grid_export': 0, 'grid_import': 0}
# 3
# 26 37 114 125
# {'grid_export': 0, 'grid_import': 0}
# 1
# 37 19 103 85
# {'grid_export': 0, 'grid_import': 0}
# 3
# 19 4 144 109
# {'grid_export': 0, 'grid_import': 20}
# episode:63 Profit:-200
# 0
# 30 0 137 100
# {'grid_export': 0, 'grid_import': 0}
# episode:64 Profit:0
# 0
# 30 0 141 100
# {'grid_export': 0, 'grid_import': 0}
# episode:65 Profit:0
# 1
# 30 6 119 95
# {'grid_export': 0, 'grid_import': 0}
# episode:66 Profit:0
# 2
# 30 15 106 117
# {'grid_export': 0, 'grid_import': 0}
# 3
# 15 27 111 123
# {'grid_export': 0, 'grid_import': 0}
# 3
# 27 44 108 125
# {'grid_export': 0, 'grid_import': 0}
# 2
# 44 29 135 85
# {'grid_export': 0, 'grid_import': 35}
# 2
# 29 14 114 106
# {'grid_export': 0, 'grid_import': 0}
# 1
# 14 0 142 121
# {'grid_export': 0, 'grid_import': 0}
# episode:67 Profit:-350
# 2
# 30 15 117 112
# {'grid_export': 0, 'grid_import': 0}
# 2
# 15 0 120 120
# {'grid_export': 0, 'grid_import': 0}
# episode:68 Profit:0
# 2
# 30 15 124 80
# {'grid_export': 0, 'grid_import': 29}
# 2
# 15 0 117 98
# {'grid_export': 0, 'grid_import': 4}
# episode:69 Profit:-330
# 3
# 30 27 111 108
# {'grid_export': 0, 'grid_import': 0}
# 1
# 27 0 128 101
# {'grid_export': 0, 'grid_import': 0}
# episode:70 Profit:0
# 2
# 30 15 115 117
# {'grid_export': 0, 'grid_import': 0}
# 0
# 15 0 138 92
# {'grid_export': 0, 'grid_import': 0}
# episode:71 Profit:0
# 3
# 30 15 133 118
# {'grid_export': 0, 'grid_import': 0}
# 0
# 15 1 137 123
# {'grid_export': 0, 'grid_import': 0}
# episode:72 Profit:0
# 2
# 30 15 137 105
# {'grid_export': 0, 'grid_import': 17}
# 1
# 15 15 128 128
# {'grid_export': 0, 'grid_import': 0}
# 3
# 15 0 148 81
# {'grid_export': 0, 'grid_import': 52}
# episode:73 Profit:-690
# 2
# 30 15 129 115
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 25 107 118
# {'grid_export': 1, 'grid_import': 0}
# 1
# 25 2 109 86
# {'grid_export': 0, 'grid_import': 0}
# episode:74 Profit:8
# 2
# 30 15 115 106
# {'grid_export': 0, 'grid_import': 0}
# 0
# 15 7 126 118
# {'grid_export': 0, 'grid_import': 0}
# 3
# 7 0 141 88
# {'grid_export': 0, 'grid_import': 38}
# episode:75 Profit:-380
# 1
# 30 40 105 118
# {'grid_export': 3, 'grid_import': 0}
# 3
# 40 25 128 80
# {'grid_export': 0, 'grid_import': 33}
# 0
# 25 14 139 128
# {'grid_export': 0, 'grid_import': 0}
# 0
# 14 0 135 108
# {'grid_export': 0, 'grid_import': 0}
# episode:76 Profit:-306
# 2
# 30 15 116 82
# {'grid_export': 0, 'grid_import': 19}
# 2
# 15 0 149 105
# {'grid_export': 0, 'grid_import': 29}
# episode:77 Profit:-480
# 1
# 30 20 133 123
# {'grid_export': 0, 'grid_import': 0}
# 2
# 20 5 123 106
# {'grid_export': 0, 'grid_import': 2}
# episode:78 Profit:-20
# 1
# 30 32 107 109
# {'grid_export': 0, 'grid_import': 0}
# 2
# 32 17 148 89
# {'grid_export': 0, 'grid_import': 44}
# 3
# 17 5 112 100
# {'grid_export': 0, 'grid_import': 0}
# episode:79 Profit:-440
# 0
# 30 8 143 121
# {'grid_export': 0, 'grid_import': 0}
# 3
# 8 5 100 97
# {'grid_export': 0, 'grid_import': 0}
# episode:80 Profit:0
# 2
# 30 15 127 104
# {'grid_export': 0, 'grid_import': 8}
# 0
# 15 2 104 91
# {'grid_export': 0, 'grid_import': 0}
# episode:81 Profit:-80
# 0
# 30 18 107 95
# {'grid_export': 0, 'grid_import': 0}
# 0
# 18 14 112 108
# {'grid_export': 0, 'grid_import': 0}
# 3
# 14 0 140 85
# {'grid_export': 0, 'grid_import': 40}
# episode:82 Profit:-400
# 2
# 30 15 100 125
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 7 112 104
# {'grid_export': 0, 'grid_import': 0}
# 2
# 7 0 125 97
# {'grid_export': 0, 'grid_import': 13}
# episode:83 Profit:-130
# 2
# 30 15 143 95
# {'grid_export': 0, 'grid_import': 33}
# 0
# 15 14 125 124
# {'grid_export': 0, 'grid_import': 0}
# 2
# 14 0 120 113
# {'grid_export': 0, 'grid_import': 0}
# episode:84 Profit:-330
# 1
# 30 6 106 82
# {'grid_export': 0, 'grid_import': 0}
# episode:85 Profit:0
# 0
# 30 28 127 125
# {'grid_export': 0, 'grid_import': 0}
# 3
# 28 13 127 97
# {'grid_export': 0, 'grid_import': 15}
# 1
# 13 8 122 117
# {'grid_export': 0, 'grid_import': 0}
# 0
# 8 0 116 101
# {'grid_export': 0, 'grid_import': 0}
# episode:86 Profit:-150
# 0
# 30 40 106 124
# {'grid_export': 8, 'grid_import': 0}
# 1
# 40 19 122 101
# {'grid_export': 0, 'grid_import': 0}
# 2
# 19 4 138 118
# {'grid_export': 0, 'grid_import': 5}
# episode:87 Profit:14
# 3
# 30 40 108 118
# {'grid_export': 0, 'grid_import': 0}
# 1
# 40 6 149 115
# {'grid_export': 0, 'grid_import': 0}
# episode:88 Profit:0
# 3
# 30 15 136 84
# {'grid_export': 0, 'grid_import': 37}
# 1
# 15 25 109 124
# {'grid_export': 5, 'grid_import': 0}
# 2
# 25 10 107 118
# {'grid_export': 0, 'grid_import': 0}
# 2
# 10 0 117 87
# {'grid_export': 0, 'grid_import': 15}
# episode:89 Profit:-480
# 1
# 30 17 113 100
# {'grid_export': 0, 'grid_import': 0}
# 2
# 17 2 131 106
# {'grid_export': 0, 'grid_import': 10}
# episode:90 Profit:-100
# 3
# 30 21 128 119
# {'grid_export': 0, 'grid_import': 0}
# 0
# 21 9 135 123
# {'grid_export': 0, 'grid_import': 0}
# 0
# 9 18 108 117
# {'grid_export': 0, 'grid_import': 0}
# 1
# 18 28 104 128
# {'grid_export': 14, 'grid_import': 0}
# 2
# 28 13 116 87
# {'grid_export': 0, 'grid_import': 14}
# 3
# 13 0 128 109
# {'grid_export': 0, 'grid_import': 4}
# episode:91 Profit:-68
# 2
# 30 15 119 123
# {'grid_export': 0, 'grid_import': 0}
# 2
# 15 0 129 123
# {'grid_export': 0, 'grid_import': 0}
# episode:92 Profit:0
# 3
# 30 15 131 100
# {'grid_export': 0, 'grid_import': 16}
# 1
# 15 0 140 85
# {'grid_export': 0, 'grid_import': 0}
# episode:93 Profit:-160
# 0
# 30 30 116 116
# {'grid_export': 0, 'grid_import': 0}
# 3
# 30 18 129 117
# {'grid_export': 0, 'grid_import': 0}
# 3
# 18 3 121 82
# {'grid_export': 0, 'grid_import': 24}
# episode:94 Profit:-240
# 1
# 30 0 143 93
# {'grid_export': 0, 'grid_import': 0}
# episode:95 Profit:0
# 1
# 30 16 106 92
# {'grid_export': 0, 'grid_import': 0}
# 1
# 16 26 116 129
# {'grid_export': 3, 'grid_import': 0}
# 3
# 26 36 109 119
# {'grid_export': 0, 'grid_import': 0}
# 1
# 36 0 133 85
# {'grid_export': 0, 'grid_import': 0}
# episode:96 Profit:24
# 0
# 30 0 145 89
# {'grid_export': 0, 'grid_import': 0}
# episode:97 Profit:0
# 3
# 30 35 111 116
# {'grid_export': 0, 'grid_import': 0}
# 1
# 35 44 118 127
# {'grid_export': 0, 'grid_import': 0}
# 0
# 44 0 136 89
# {'grid_export': 0, 'grid_import': 0}
# episode:98 Profit:0
# 2
# 30 15 149 82
# {'grid_export': 0, 'grid_import': 52}
# 1
# 15 0 141 84
# {'grid_export': 0, 'grid_import': 0}
# episode:99 Profit:-520
# 2
# 30 15 126 123
# {'grid_export': 0, 'grid_import': 0}
# 0
# 15 25 108 120
# {'grid_export': 2, 'grid_import': 0}
# 1
# 25 0 132 88
# {'grid_export': 0, 'grid_import': 0}
# episode:100 Profit:16
# 3
# 30 15 116 90
# {'grid_export': 0, 'grid_import': 11}
# 2
# 15 0 100 86
# {'grid_export': 0, 'grid_import': 0}
# episode:101 Profit:-110
# 2
# 30 15 145 84
# {'grid_export': 0, 'grid_import': 46}
# 3
# 15 0 109 82
# {'grid_export': 0, 'grid_import': 12}
# episode:102 Profit:-580
# 1
# 30 30 100 100
# {'grid_export': 0, 'grid_import': 0}
# 2
# 30 15 128 84
# {'grid_export': 0, 'grid_import': 29}
# 2
# 15 0 143 80
# {'grid_export': 0, 'grid_import': 48}
# episode:103 Profit:-770
# 2
# 30 15 148 125
# {'grid_export': 0, 'grid_import': 8}
# 2
# 15 0 134 115
# {'grid_export': 0, 'grid_import': 4}
# episode:104 Profit:-120
# 2
# 30 15 118 100
# {'grid_export': 0, 'grid_import': 3}
# 0
# 15 16 109 110
# {'grid_export': 0, 'grid_import': 0}
# 1
# 16 0 111 90
# {'grid_export': 0, 'grid_import': 0}
# episode:105 Profit:-30
# 3
# 30 17 131 118
# {'grid_export': 0, 'grid_import': 0}
# 1
# 17 0 148 110
# {'grid_export': 0, 'grid_import': 0}
# episode:106 Profit:0
# 1
# 30 9 111 90
# {'grid_export': 0, 'grid_import': 0}
# 2
# 9 0 142 106
# {'grid_export': 0, 'grid_import': 21}
# episode:107 Profit:-210
# 1
# 30 0 145 105
# {'grid_export': 0, 'grid_import': 0}
# episode:108 Profit:0
# 3
# 30 15 132 97
# {'grid_export': 0, 'grid_import': 20}
# 1
# 15 0 130 104
# {'grid_export': 0, 'grid_import': 0}
# episode:109 Profit:-200
# 3
# 30 23 116 109
# {'grid_export': 0, 'grid_import': 0}
# 3
# 23 8 135 85
# {'grid_export': 0, 'grid_import': 35}
# 1
# 8 0 116 106
# {'grid_export': 0, 'grid_import': 0}
# episode:110 Profit:-350
# 0
# 30 0 139 101
# {'grid_export': 0, 'grid_import': 0}
# episode:111 Profit:0
# 1
# 30 34 112 116
# {'grid_export': 0, 'grid_import': 0}
# 3
# 34 27 111 104
# {'grid_export': 0, 'grid_import': 0}
# 3
# 27 39 116 128
# {'grid_export': 0, 'grid_import': 0}
# 0
# 39 20 106 87
# {'grid_export': 0, 'grid_import': 0}
# 3
# 20 5 112 82
# {'grid_export': 0, 'grid_import': 15}
# episode:112 Profit:-150
# 2
# 30 15 117 116
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 0 137 102
# {'grid_export': 0, 'grid_import': 0}
# episode:113 Profit:0
# 1
# 30 40 100 120
# {'grid_export': 10, 'grid_import': 0}
# 1
# 40 17 128 105
# {'grid_export': 0, 'grid_import': 0}
# 0
# 17 0 141 104
# {'grid_export': 0, 'grid_import': 0}
# episode:114 Profit:80
# 0
# 30 28 122 120
# {'grid_export': 0, 'grid_import': 0}
# 3
# 28 20 116 108
# {'grid_export': 0, 'grid_import': 0}
# 0
# 20 0 134 101
# {'grid_export': 0, 'grid_import': 0}
# episode:115 Profit:0
# 2
# 30 15 132 83
# {'grid_export': 0, 'grid_import': 34}
# 3
# 15 0 145 99
# {'grid_export': 0, 'grid_import': 31}
# episode:116 Profit:-650
# 0
# 30 0 140 109
# {'grid_export': 0, 'grid_import': 0}
# episode:117 Profit:0
# 2
# 30 15 104 101
# {'grid_export': 0, 'grid_import': 0}
# 0
# 15 2 122 109
# {'grid_export': 0, 'grid_import': 0}
# episode:118 Profit:0
# 1
# 30 9 144 123
# {'grid_export': 0, 'grid_import': 0}
# 3
# 9 0 111 89
# {'grid_export': 0, 'grid_import': 7}
# episode:119 Profit:-70
# 1
# 30 0 131 94
# {'grid_export': 0, 'grid_import': 0}
# episode:120 Profit:0
# 1
# 30 33 121 124
# {'grid_export': 0, 'grid_import': 0}
# 1
# 33 15 126 108
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 0 138 114
# {'grid_export': 0, 'grid_import': 0}
# episode:121 Profit:0
# 3
# 30 35 112 117
# {'grid_export': 0, 'grid_import': 0}
# 2
# 35 20 121 95
# {'grid_export': 0, 'grid_import': 11}
# 1
# 20 0 136 115
# {'grid_export': 0, 'grid_import': 0}
# episode:122 Profit:-110
# 2
# 30 15 146 125
# {'grid_export': 0, 'grid_import': 6}
# 2
# 15 0 148 86
# {'grid_export': 0, 'grid_import': 47}
# episode:123 Profit:-530
# 2
# 30 15 127 86
# {'grid_export': 0, 'grid_import': 26}
# 3
# 15 0 144 85
# {'grid_export': 0, 'grid_import': 44}
# episode:124 Profit:-700
# 3
# 30 15 131 102
# {'grid_export': 0, 'grid_import': 14}
# 1
# 15 0 129 85
# {'grid_export': 0, 'grid_import': 0}
# episode:125 Profit:-140
# 3
# 30 15 142 100
# {'grid_export': 0, 'grid_import': 27}
# 0
# 15 0 138 103
# {'grid_export': 0, 'grid_import': 0}
# episode:126 Profit:-270
# 1
# 30 0 136 99
# {'grid_export': 0, 'grid_import': 0}
# episode:127 Profit:0
# 0
# 30 0 148 107
# {'grid_export': 0, 'grid_import': 0}
# episode:128 Profit:0
# 1
# 30 40 112 125
# {'grid_export': 3, 'grid_import': 0}
# 2
# 40 25 132 110
# {'grid_export': 0, 'grid_import': 7}
# 0
# 25 16 130 121
# {'grid_export': 0, 'grid_import': 0}
# 1
# 16 6 114 104
# {'grid_export': 0, 'grid_import': 0}
# episode:129 Profit:-46
# 1
# 30 6 117 93
# {'grid_export': 0, 'grid_import': 0}
# episode:130 Profit:0
# 2
# 30 15 148 103
# {'grid_export': 0, 'grid_import': 30}
# 2
# 15 0 147 105
# {'grid_export': 0, 'grid_import': 27}
# episode:131 Profit:-570
# 3
# 30 15 121 88
# {'grid_export': 0, 'grid_import': 18}
# 2
# 15 0 118 102
# {'grid_export': 0, 'grid_import': 1}
# episode:132 Profit:-190
# 0
# 30 0 124 89
# {'grid_export': 0, 'grid_import': 0}
# episode:133 Profit:0
# 0
# 30 1 112 83
# {'grid_export': 0, 'grid_import': 0}
# episode:134 Profit:0
# 3
# 30 15 138 106
# {'grid_export': 0, 'grid_import': 17}
# 2
# 15 0 139 99
# {'grid_export': 0, 'grid_import': 25}
# episode:135 Profit:-420
# 3
# 30 20 125 115
# {'grid_export': 0, 'grid_import': 0}
# 0
# 20 10 114 104
# {'grid_export': 0, 'grid_import': 0}
# 3
# 10 0 137 101
# {'grid_export': 0, 'grid_import': 21}
# episode:136 Profit:-210
# 2
# 30 15 109 89
# {'grid_export': 0, 'grid_import': 5}
# 2
# 15 0 117 92
# {'grid_export': 0, 'grid_import': 10}
# episode:137 Profit:-150
# 1
# 30 0 146 81
# {'grid_export': 0, 'grid_import': 0}
# episode:138 Profit:0
# 0
# 30 0 145 88
# {'grid_export': 0, 'grid_import': 0}
# episode:139 Profit:0
# 0
# 30 6 144 120
# {'grid_export': 0, 'grid_import': 0}
# episode:140 Profit:0
# 1
# 30 21 129 120
# {'grid_export': 0, 'grid_import': 0}
# 3
# 21 28 102 109
# {'grid_export': 0, 'grid_import': 0}
# 0
# 28 0 140 85
# {'grid_export': 0, 'grid_import': 0}
# episode:141 Profit:0
# 3
# 30 15 143 94
# {'grid_export': 0, 'grid_import': 34}
# 1
# 15 17 117 119
# {'grid_export': 0, 'grid_import': 0}
# 1
# 17 5 132 120
# {'grid_export': 0, 'grid_import': 0}
# episode:142 Profit:-340
# 0
# 30 20 112 102
# {'grid_export': 0, 'grid_import': 0}
# 1
# 20 9 127 116
# {'grid_export': 0, 'grid_import': 0}
# 2
# 9 0 132 114
# {'grid_export': 0, 'grid_import': 3}
# episode:143 Profit:-30
# 1
# 30 40 111 122
# {'grid_export': 1, 'grid_import': 0}
# 1
# 40 26 123 109
# {'grid_export': 0, 'grid_import': 0}
# 3
# 26 36 114 124
# {'grid_export': 0, 'grid_import': 0}
# 3
# 36 48 116 128
# {'grid_export': 0, 'grid_import': 0}
# 3
# 48 48 120 120
# {'grid_export': 0, 'grid_import': 0}
# 0
# 48 50 102 126
# {'grid_export': 14, 'grid_import': 0}
# 2
# 50 35 148 119
# {'grid_export': 0, 'grid_import': 14}
# 1
# 35 0 138 90
# {'grid_export': 0, 'grid_import': 0}
# episode:144 Profit:-20
# 2
# 30 15 123 128
# {'grid_export': 0, 'grid_import': 0}
# 3
# 15 0 138 103
# {'grid_export': 0, 'grid_import': 20}
# episode:145 Profit:-200
# 0
# 30 34 123 127
# {'grid_export': 0, 'grid_import': 0}
# 2
# 34 19 105 104
# {'grid_export': 0, 'grid_import': 0}
# 3
# 19 4 143 98
# {'grid_export': 0, 'grid_import': 30}
# episode:146 Profit:-300
# 3
# 30 19 108 97
# {'grid_export': 0, 'grid_import': 0}
# 1
# 19 14 125 120
# {'grid_export': 0, 'grid_import': 0}
# 0
# 14 0 145 98
# {'grid_export': 0, 'grid_import': 0}
# episode:147 Profit:0
# 1
# 30 0 134 84
# {'grid_export': 0, 'grid_import': 0}
# episode:148 Profit:0
# 3
# 30 34 111 115
# {'grid_export': 0, 'grid_import': 0}
# 2
# 34 19 116 100
# {'grid_export': 0, 'grid_import': 1}
# 0
# 19 0 125 106
# {'grid_export': 0, 'grid_import': 0}
# episode:149 Profit:-10
# 3
# 30 15 140 100
# {'grid_export': 0, 'grid_import': 25}
# 0
# 15 0 143 89
# {'grid_export': 0, 'grid_import': 0}
# episode:150 Profit:-250
# 3
# 30 15 137 106
# {'grid_export': 0, 'grid_import': 16}
# 1
# 15 0 114 82
# {'grid_export': 0, 'grid_import': 0}
# episode:151 Profit:-160
# 1
# 30 40 105 125
# {'grid_export': 10, 'grid_import': 0}
# 1
# 40 0 138 86
# {'grid_export': 0, 'grid_import': 0}
# episode:152 Profit:80
# 1
# 30 12 105 87
# {'grid_export': 0, 'grid_import': 0}
# 1
# 12 0 111 88
# {'grid_export': 0, 'grid_import': 0}
# episode:153 Profit:0
# 3
# 30 15 136 104
# {'grid_export': 0, 'grid_import': 17}
# 0
# 15 0 100 84
# {'grid_export': 0, 'grid_import': 0}
# episode:154 Profit:-170
# 2
# 30 15 143 99
# {'grid_export': 0, 'grid_import': 29}
# 2
# 15 0 137 87
# {'grid_export': 0, 'grid_import': 35}
# episode:155 Profit:-640
# 2
# 30 15 135 82
# {'grid_export': 0, 'grid_import': 38}
# 1
# 15 0 143 81
# {'grid_export': 0, 'grid_import': 0}
# episode:156 Profit:-380
# 0
# 30 40 106 118
# {'grid_export': 2, 'grid_import': 0}
# 0
# 40 0 137 82
# {'grid_export': 0, 'grid_import': 0}
# episode:157 Profit:16
# 1
# 30 7 116 93
# {'grid_export': 0, 'grid_import': 0}
# 3
# 7 1 126 120
# {'grid_export': 0, 'grid_import': 0}
# episode:158 Profit:0
# 0
# 30 0 134 83
# {'grid_export': 0, 'grid_import': 0}
# episode:159 Profit:0
# 1
# 30 40 101 112
# {'grid_export': 1, 'grid_import': 0}
# 3
# 40 25 116 92
# {'grid_export': 0, 'grid_import': 9}
# 3
# 25 10 113 88
# {'grid_export': 0, 'grid_import': 10}
# 1
# 10 0 135 90
# {'grid_export': 0, 'grid_import': 0}
# episode:160 Profit:-182
# 3
# 30 23 126 119
# {'grid_export': 0, 'grid_import': 0}
# 3
# 23 8 144 85
# {'grid_export': 0, 'grid_import': 44}
# 2
# 8 0 145 83
# {'grid_export': 0, 'grid_import': 47}
# episode:161 Profit:-910
# 0
# 30 0 126 85
# {'grid_export': 0, 'grid_import': 0}
# episode:162 Profit:0
# 2
# 30 15 140 115
# {'grid_export': 0, 'grid_import': 10}
# 1
# 15 0 147 111
# {'grid_export': 0, 'grid_import': 0}
# episode:163 Profit:-100
# 2
# 30 15 103 107
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 0 117 86
# {'grid_export': 0, 'grid_import': 0}
# episode:164 Profit:0
# 1
# 30 35 106 111
# {'grid_export': 0, 'grid_import': 0}
# 2
# 35 20 130 84
# {'grid_export': 0, 'grid_import': 31}
# 0
# 20 30 106 123
# {'grid_export': 7, 'grid_import': 0}
# 3
# 30 15 144 111
# {'grid_export': 0, 'grid_import': 18}
# 1
# 15 0 137 114
# {'grid_export': 0, 'grid_import': 0}
# episode:165 Profit:-434
# 3
# 30 50 103 129
# {'grid_export': 0, 'grid_import': 0}
# 0
# 50 39 107 96
# {'grid_export': 0, 'grid_import': 0}
# 0
# 39 49 102 125
# {'grid_export': 13, 'grid_import': 0}
# 3
# 49 34 128 98
# {'grid_export': 0, 'grid_import': 15}
# 3
# 34 19 148 110
# {'grid_export': 0, 'grid_import': 23}
# 0
# 19 0 113 91
# {'grid_export': 0, 'grid_import': 0}
# episode:166 Profit:-276
# 0
# 30 0 136 103
# {'grid_export': 0, 'grid_import': 0}
# episode:167 Profit:0
# 1
# 30 23 128 121
# {'grid_export': 0, 'grid_import': 0}
# 1
# 23 0 113 82
# {'grid_export': 0, 'grid_import': 0}
# episode:168 Profit:0
# 0
# 30 3 147 120
# {'grid_export': 0, 'grid_import': 0}
# episode:169 Profit:0
# 3
# 30 30 108 108
# {'grid_export': 0, 'grid_import': 0}
# 1
# 30 21 131 122
# {'grid_export': 0, 'grid_import': 0}
# 1
# 21 0 124 83
# {'grid_export': 0, 'grid_import': 0}
# episode:170 Profit:0
# 2
# 30 15 140 117
# {'grid_export': 0, 'grid_import': 8}
# 2
# 15 0 133 92
# {'grid_export': 0, 'grid_import': 26}
# episode:171 Profit:-340
# 3
# 30 22 113 105
# {'grid_export': 0, 'grid_import': 0}
# 1
# 22 0 131 95
# {'grid_export': 0, 'grid_import': 0}
# episode:172 Profit:0
# 3
# 30 33 106 109
# {'grid_export': 0, 'grid_import': 0}
# 0
# 33 3 141 111
# {'grid_export': 0, 'grid_import': 0}
# episode:173 Profit:0
# 1
# 30 20 127 117
# {'grid_export': 0, 'grid_import': 0}
# 3
# 20 5 147 120
# {'grid_export': 0, 'grid_import': 12}
# episode:174 Profit:-120
# 3
# 30 15 148 119
# {'grid_export': 0, 'grid_import': 14}
# 0
# 15 20 115 120
# {'grid_export': 0, 'grid_import': 0}
# 0
# 20 0 119 94
# {'grid_export': 0, 'grid_import': 0}
# episode:175 Profit:-140
# 0
# 30 24 120 114
# {'grid_export': 0, 'grid_import': 0}
# 1
# 24 0 138 112
# {'grid_export': 0, 'grid_import': 0}
# episode:176 Profit:0
# 0
# 30 0 133 91
# {'grid_export': 0, 'grid_import': 0}
# episode:177 Profit:0
# 0
# 30 5 117 92
# {'grid_export': 0, 'grid_import': 0}
# episode:178 Profit:0
# 0
# 30 40 101 124
# {'grid_export': 13, 'grid_import': 0}
# 0
# 40 0 137 92
# {'grid_export': 0, 'grid_import': 0}
# episode:179 Profit:104
# 1
# 30 21 135 126
# {'grid_export': 0, 'grid_import': 0}
# 1
# 21 26 122 127
# {'grid_export': 0, 'grid_import': 0}
# 0
# 26 0 121 85
# {'grid_export': 0, 'grid_import': 0}
# episode:180 Profit:0
# 0
# 30 0 141 88
# {'grid_export': 0, 'grid_import': 0}
# episode:181 Profit:0
# 1
# 30 11 103 84
# {'grid_export': 0, 'grid_import': 0}
# 0
# 11 0 110 99
# {'grid_export': 0, 'grid_import': 0}
# episode:182 Profit:0
# 0
# 30 0 140 98
# {'grid_export': 0, 'grid_import': 0}
# episode:183 Profit:0
# 0
# 30 39 116 125
# {'grid_export': 0, 'grid_import': 0}
# 1
# 39 1 131 93
# {'grid_export': 0, 'grid_import': 0}
# episode:184 Profit:0
# 3
# 30 15 137 84
# {'grid_export': 0, 'grid_import': 38}
# 1
# 15 0 112 93
# {'grid_export': 0, 'grid_import': 0}
# episode:185 Profit:-380
# 3
# 30 15 138 83
# {'grid_export': 0, 'grid_import': 40}
# 0
# 15 25 106 123
# {'grid_export': 7, 'grid_import': 0}
# 2
# 25 10 114 112
# {'grid_export': 0, 'grid_import': 0}
# 0
# 10 0 136 126
# {'grid_export': 0, 'grid_import': 0}
# episode:186 Profit:-344
# 1
# 30 0 131 91
# {'grid_export': 0, 'grid_import': 0}
# episode:187 Profit:0
# 1
# 30 0 146 101
# {'grid_export': 0, 'grid_import': 0}
# episode:188 Profit:0
# 0
# 30 31 103 104
# {'grid_export': 0, 'grid_import': 0}
# 0
# 31 15 138 122
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 0 140 107
# {'grid_export': 0, 'grid_import': 0}
# episode:189 Profit:0
# 3
# 30 47 111 128
# {'grid_export': 0, 'grid_import': 0}
# 2
# 47 32 110 126
# {'grid_export': 0, 'grid_import': 0}
# 3
# 32 23 130 121
# {'grid_export': 0, 'grid_import': 0}
# 1
# 23 0 147 112
# {'grid_export': 0, 'grid_import': 0}
# episode:190 Profit:0
# 0
# 30 0 125 85
# {'grid_export': 0, 'grid_import': 0}
# episode:191 Profit:0
# 0
# 30 27 132 129
# {'grid_export': 0, 'grid_import': 0}
# 3
# 27 12 132 80
# {'grid_export': 0, 'grid_import': 37}
# 2
# 12 0 119 110
# {'grid_export': 0, 'grid_import': 0}
# episode:192 Profit:-370
# 0
# 30 12 135 117
# {'grid_export': 0, 'grid_import': 0}
# 3
# 12 11 129 128
# {'grid_export': 0, 'grid_import': 0}
# 0
# 11 0 139 88
# {'grid_export': 0, 'grid_import': 0}
# episode:193 Profit:0
# 1
# 30 24 106 100
# {'grid_export': 0, 'grid_import': 0}
# 0
# 24 0 128 94
# {'grid_export': 0, 'grid_import': 0}
# episode:194 Profit:0
# 0
# 30 28 125 123
# {'grid_export': 0, 'grid_import': 0}
# 1
# 28 0 142 109
# {'grid_export': 0, 'grid_import': 0}
# episode:195 Profit:0
# 3
# 30 15 144 117
# {'grid_export': 0, 'grid_import': 12}
# 2
# 15 0 105 104
# {'grid_export': 0, 'grid_import': 0}
# episode:196 Profit:-120
# 2
# 30 15 123 110
# {'grid_export': 0, 'grid_import': 0}
# 3
# 15 38 105 128
# {'grid_export': 0, 'grid_import': 0}
# 3
# 38 23 107 88
# {'grid_export': 0, 'grid_import': 4}
# 0
# 23 0 147 117
# {'grid_export': 0, 'grid_import': 0}
# episode:197 Profit:-40
# 0
# 30 24 121 115
# {'grid_export': 0, 'grid_import': 0}
# 3
# 24 37 104 117
# {'grid_export': 0, 'grid_import': 0}
# 1
# 37 37 109 109
# {'grid_export': 0, 'grid_import': 0}
# 0
# 37 1 148 112
# {'grid_export': 0, 'grid_import': 0}
# episode:198 Profit:0
# 1
# 30 40 112 124
# {'grid_export': 2, 'grid_import': 0}
# 0
# 40 38 116 114
# {'grid_export': 0, 'grid_import': 0}
# 0
# 38 25 126 113
# {'grid_export': 0, 'grid_import': 0}
# 2
# 25 10 144 104
# {'grid_export': 0, 'grid_import': 25}
# 2
# 10 0 100 108
# {'grid_export': 0, 'grid_import': 0}
# episode:199 Profit:-234
# 2
# 30 15 122 83
# {'grid_export': 0, 'grid_import': 24}
# 2
# 15 0 138 93
# {'grid_export': 0, 'grid_import': 30}
# episode:200 Profit:-540
# 0
# 30 40 112 125
# {'grid_export': 3, 'grid_import': 0}
# 3
# 40 25 102 87
# {'grid_export': 0, 'grid_import': 0}
# 2
# 25 10 141 126
# {'grid_export': 0, 'grid_import': 0}
# 1
# 10 0 147 129
# {'grid_export': 0, 'grid_import': 0}
# episode:201 Profit:24
# 1
# 30 0 146 83
# {'grid_export': 0, 'grid_import': 0}
# episode:202 Profit:0
# 1
# 30 4 143 117
# {'grid_export': 0, 'grid_import': 0}
# episode:203 Profit:0
# 0
# 30 30 129 129
# {'grid_export': 0, 'grid_import': 0}
# 3
# 30 15 125 104
# {'grid_export': 0, 'grid_import': 6}
# 1
# 15 0 135 80
# {'grid_export': 0, 'grid_import': 0}
# episode:204 Profit:-60
# 1
# 30 1 122 93
# {'grid_export': 0, 'grid_import': 0}
# episode:205 Profit:0
# 0
# 30 1 128 99
# {'grid_export': 0, 'grid_import': 0}
# episode:206 Profit:0
# 0
# 30 0 129 92
# {'grid_export': 0, 'grid_import': 0}
# episode:207 Profit:0
# 1
# 30 39 112 121
# {'grid_export': 0, 'grid_import': 0}
# 3
# 39 32 132 125
# {'grid_export': 0, 'grid_import': 0}
# 3
# 32 17 141 103
# {'grid_export': 0, 'grid_import': 23}
# 3
# 17 2 131 112
# {'grid_export': 0, 'grid_import': 4}
# episode:208 Profit:-270
# 3
# 30 15 133 89
# {'grid_export': 0, 'grid_import': 29}
# 2
# 15 0 110 111
# {'grid_export': 0, 'grid_import': 0}
# episode:209 Profit:-290
# 1
# 30 0 141 104
# {'grid_export': 0, 'grid_import': 0}
# episode:210 Profit:0
# 2
# 30 15 109 84
# {'grid_export': 0, 'grid_import': 10}
# 0
# 15 0 121 90
# {'grid_export': 0, 'grid_import': 0}
# episode:211 Profit:-100
# 2
# 30 15 142 109
# {'grid_export': 0, 'grid_import': 18}
# 2
# 15 0 100 104
# {'grid_export': 0, 'grid_import': 0}
# episode:212 Profit:-180
# 1
# 30 20 115 105
# {'grid_export': 0, 'grid_import': 0}
# 3
# 20 6 112 98
# {'grid_export': 0, 'grid_import': 0}
# episode:213 Profit:0
# 1
# 30 0 141 110
# {'grid_export': 0, 'grid_import': 0}
# episode:214 Profit:0
# 2
# 30 15 117 129
# {'grid_export': 0, 'grid_import': 0}
# 0
# 15 4 101 90
# {'grid_export': 0, 'grid_import': 0}
# episode:215 Profit:0
# 0
# 30 30 125 125
# {'grid_export': 0, 'grid_import': 0}
# 1
# 30 40 101 120
# {'grid_export': 9, 'grid_import': 0}
# 3
# 40 25 133 102
# {'grid_export': 0, 'grid_import': 16}
# 2
# 25 10 128 81
# {'grid_export': 0, 'grid_import': 32}
# 2
# 10 0 111 114
# {'grid_export': 0, 'grid_import': 0}
# episode:216 Profit:-408
# 3
# 30 18 111 99
# {'grid_export': 0, 'grid_import': 0}
# 3
# 18 30 103 115
# {'grid_export': 0, 'grid_import': 0}
# 3
# 30 15 137 98
# {'grid_export': 0, 'grid_import': 24}
# 1
# 15 0 105 86
# {'grid_export': 0, 'grid_import': 0}
# episode:217 Profit:-240
# 0
# 30 0 133 100
# {'grid_export': 0, 'grid_import': 0}
# episode:218 Profit:0
# 1
# 30 34 121 125
# {'grid_export': 0, 'grid_import': 0}
# 1
# 34 18 134 118
# {'grid_export': 0, 'grid_import': 0}
# 2
# 18 3 142 96
# {'grid_export': 0, 'grid_import': 31}
# episode:219 Profit:-310
# 3
# 30 50 105 127
# {'grid_export': 0, 'grid_import': 0}
# 2
# 50 35 105 92
# {'grid_export': 0, 'grid_import': 0}
# 0
# 35 45 106 118
# {'grid_export': 2, 'grid_import': 0}
# 2
# 45 30 126 92
# {'grid_export': 0, 'grid_import': 19}
# 3
# 30 15 134 82
# {'grid_export': 0, 'grid_import': 37}
# 2
# 15 0 100 111
# {'grid_export': 0, 'grid_import': 0}
# episode:220 Profit:-544
# 1
# 30 38 117 125
# {'grid_export': 0, 'grid_import': 0}
# 3
# 38 30 117 109
# {'grid_export': 0, 'grid_import': 0}
# 0
# 30 39 103 112
# {'grid_export': 0, 'grid_import': 0}
# 3
# 39 24 147 93
# {'grid_export': 0, 'grid_import': 39}
# 2
# 24 9 115 100
# {'grid_export': 0, 'grid_import': 0}
# 0
# 9 0 129 91
# {'grid_export': 0, 'grid_import': 0}
# episode:221 Profit:-390
# 3
# 30 15 130 81
# {'grid_export': 0, 'grid_import': 34}
# 2
# 15 0 138 119
# {'grid_export': 0, 'grid_import': 4}
# episode:222 Profit:-380
# 3
# 30 15 148 129
# {'grid_export': 0, 'grid_import': 4}
# 3
# 15 0 134 95
# {'grid_export': 0, 'grid_import': 24}
# episode:223 Profit:-280
# 1
# 30 30 104 104
# {'grid_export': 0, 'grid_import': 0}
# 1
# 30 0 128 87
# {'grid_export': 0, 'grid_import': 0}
# episode:224 Profit:0
# 1
# 30 40 109 120
# {'grid_export': 1, 'grid_import': 0}
# 2
# 40 25 147 95
# {'grid_export': 0, 'grid_import': 37}
# 2
# 25 10 129 121
# {'grid_export': 0, 'grid_import': 0}
# 3
# 10 0 143 97
# {'grid_export': 0, 'grid_import': 31}
# episode:225 Profit:-672
# 0
# 30 32 112 114
# {'grid_export': 0, 'grid_import': 0}
# 0
# 32 0 143 87
# {'grid_export': 0, 'grid_import': 0}
# episode:226 Profit:0
# 0
# 30 0 118 82
# {'grid_export': 0, 'grid_import': 0}
# episode:227 Profit:0
# 3
# 30 15 146 91
# {'grid_export': 0, 'grid_import': 40}
# 2
# 15 0 133 122
# {'grid_export': 0, 'grid_import': 0}
# episode:228 Profit:-400
# 1
# 30 26 107 103
# {'grid_export': 0, 'grid_import': 0}
# 3
# 26 11 114 84
# {'grid_export': 0, 'grid_import': 15}
# 1
# 11 0 113 83
# {'grid_export': 0, 'grid_import': 0}
# episode:229 Profit:-150
# 1
# 30 0 130 85
# {'grid_export': 0, 'grid_import': 0}
# episode:230 Profit:0
# 1
# 30 12 120 102
# {'grid_export': 0, 'grid_import': 0}
# 3
# 12 0 126 84
# {'grid_export': 0, 'grid_import': 27}
# episode:231 Profit:-270
# 1
# 30 0 149 91
# {'grid_export': 0, 'grid_import': 0}
# episode:232 Profit:0
# 0
# 30 0 141 89
# {'grid_export': 0, 'grid_import': 0}
# episode:233 Profit:0
# 2
# 30 15 147 86
# {'grid_export': 0, 'grid_import': 46}
# 1
# 15 20 121 126
# {'grid_export': 0, 'grid_import': 0}
# 1
# 20 0 138 98
# {'grid_export': 0, 'grid_import': 0}
# episode:234 Profit:-460
# 2
# 30 15 118 99
# {'grid_export': 0, 'grid_import': 4}
# 0
# 15 0 136 93
# {'grid_export': 0, 'grid_import': 0}
# episode:235 Profit:-40
# 3
# 30 18 127 115
# {'grid_export': 0, 'grid_import': 0}
# 1
# 18 0 149 82
# {'grid_export': 0, 'grid_import': 0}
# episode:236 Profit:0
# 2
# 30 15 138 97
# {'grid_export': 0, 'grid_import': 26}
# 2
# 15 0 134 102
# {'grid_export': 0, 'grid_import': 17}
# episode:237 Profit:-430
# 0
# 30 9 141 120
# {'grid_export': 0, 'grid_import': 0}
# 2
# 9 0 141 111
# {'grid_export': 0, 'grid_import': 15}
# episode:238 Profit:-150
# 3
# 30 15 116 94
# {'grid_export': 0, 'grid_import': 7}
# 3
# 15 0 114 85
# {'grid_export': 0, 'grid_import': 14}
# episode:239 Profit:-210
# 1
# 30 34 109 113
# {'grid_export': 0, 'grid_import': 0}
# 1
# 34 9 132 107
# {'grid_export': 0, 'grid_import': 0}
# 1
# 9 19 103 120
# {'grid_export': 7, 'grid_import': 0}
# 3
# 19 5 134 120
# {'grid_export': 0, 'grid_import': 0}
# episode:240 Profit:56
# 1
# 30 14 113 97
# {'grid_export': 0, 'grid_import': 0}
# 2
# 14 0 106 95
# {'grid_export': 0, 'grid_import': 0}
# episode:241 Profit:0
# 0
# 30 8 112 90
# {'grid_export': 0, 'grid_import': 0}
# 0
# 8 0 129 95
# {'grid_export': 0, 'grid_import': 0}
# episode:242 Profit:0
# 0
# 30 12 147 129
# {'grid_export': 0, 'grid_import': 0}
# 0
# 12 4 102 94
# {'grid_export': 0, 'grid_import': 0}
# episode:243 Profit:0
# 2
# 30 15 111 113
# {'grid_export': 0, 'grid_import': 0}
# 3
# 15 2 123 110
# {'grid_export': 0, 'grid_import': 0}
# episode:244 Profit:0
# 0
# 30 4 137 111
# {'grid_export': 0, 'grid_import': 0}
# episode:245 Profit:0
# 1
# 30 38 111 119
# {'grid_export': 0, 'grid_import': 0}
# 2
# 38 23 110 119
# {'grid_export': 0, 'grid_import': 0}
# 3
# 23 8 126 84
# {'grid_export': 0, 'grid_import': 27}
# 1
# 8 18 116 127
# {'grid_export': 1, 'grid_import': 0}
# 3
# 18 3 125 94
# {'grid_export': 0, 'grid_import': 16}
# episode:246 Profit:-422
# 1
# 30 9 103 82
# {'grid_export': 0, 'grid_import': 0}
# 2
# 9 0 103 124
# {'grid_export': 0, 'grid_import': 0}
# episode:247 Profit:0
# 0
# 30 0 141 106
# {'grid_export': 0, 'grid_import': 0}
# episode:248 Profit:0
# 2
# 30 15 126 106
# {'grid_export': 0, 'grid_import': 5}
# 1
# 15 0 131 113
# {'grid_export': 0, 'grid_import': 0}
# episode:249 Profit:-50
# 1
# 30 0 129 85
# {'grid_export': 0, 'grid_import': 0}
# episode:250 Profit:0
# 2
# 30 15 105 109
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 0 145 112
# {'grid_export': 0, 'grid_import': 0}
# episode:251 Profit:0
# 1
# 30 24 134 128
# {'grid_export': 0, 'grid_import': 0}
# 3
# 24 13 136 125
# {'grid_export': 0, 'grid_import': 0}
# 3
# 13 0 143 95
# {'grid_export': 0, 'grid_import': 33}
# episode:252 Profit:-330
# 2
# 30 15 120 103
# {'grid_export': 0, 'grid_import': 2}
# 2
# 15 0 134 122
# {'grid_export': 0, 'grid_import': 0}
# episode:253 Profit:-20
# 1
# 30 0 123 80
# {'grid_export': 0, 'grid_import': 0}
# episode:254 Profit:0
# 1
# 30 35 105 110
# {'grid_export': 0, 'grid_import': 0}
# 2
# 35 20 105 129
# {'grid_export': 0, 'grid_import': 0}
# 1
# 20 0 122 90
# {'grid_export': 0, 'grid_import': 0}
# episode:255 Profit:0
# 0
# 30 22 113 105
# {'grid_export': 0, 'grid_import': 0}
# 0
# 22 8 125 111
# {'grid_export': 0, 'grid_import': 0}
# 3
# 8 0 146 115
# {'grid_export': 0, 'grid_import': 16}
# episode:256 Profit:-160
# 0
# 30 0 125 83
# {'grid_export': 0, 'grid_import': 0}
# episode:257 Profit:0
# 0
# 30 2 121 93
# {'grid_export': 0, 'grid_import': 0}
# episode:258 Profit:0
# 3
# 30 15 104 80
# {'grid_export': 0, 'grid_import': 9}
# 0
# 15 0 147 89
# {'grid_export': 0, 'grid_import': 0}
# episode:259 Profit:-90
# 3
# 30 25 111 106
# {'grid_export': 0, 'grid_import': 0}
# 3
# 25 16 118 109
# {'grid_export': 0, 'grid_import': 0}
# 3
# 16 1 108 84
# {'grid_export': 0, 'grid_import': 9}
# episode:260 Profit:-90
# 1
# 30 34 104 108
# {'grid_export': 0, 'grid_import': 0}
# 1
# 34 9 111 86
# {'grid_export': 0, 'grid_import': 0}
# 3
# 9 0 122 95
# {'grid_export': 0, 'grid_import': 12}
# episode:261 Profit:-120
# 1
# 30 0 124 83
# {'grid_export': 0, 'grid_import': 0}
# episode:262 Profit:0
# 3
# 30 15 105 90
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 0 116 100
# {'grid_export': 0, 'grid_import': 0}
# episode:263 Profit:0
# 0
# 30 0 138 92
# {'grid_export': 0, 'grid_import': 0}
# episode:264 Profit:0
# 2
# 30 15 122 90
# {'grid_export': 0, 'grid_import': 17}
# 1
# 15 0 102 84
# {'grid_export': 0, 'grid_import': 0}
# episode:265 Profit:-170
# 1
# 30 32 104 106
# {'grid_export': 0, 'grid_import': 0}
# 1
# 32 0 134 99
# {'grid_export': 0, 'grid_import': 0}
# episode:266 Profit:0
# 3
# 30 15 114 85
# {'grid_export': 0, 'grid_import': 14}
# 0
# 15 4 123 112
# {'grid_export': 0, 'grid_import': 0}
# episode:267 Profit:-140
# 3
# 30 50 101 129
# {'grid_export': 0, 'grid_import': 0}
# 1
# 50 30 104 84
# {'grid_export': 0, 'grid_import': 0}
# 0
# 30 21 135 126
# {'grid_export': 0, 'grid_import': 0}
# 1
# 21 0 143 117
# {'grid_export': 0, 'grid_import': 0}
# episode:268 Profit:0
# 0
# 30 0 129 86
# {'grid_export': 0, 'grid_import': 0}
# episode:269 Profit:0
# 3
# 30 29 102 101
# {'grid_export': 0, 'grid_import': 0}
# 1
# 29 0 149 95
# {'grid_export': 0, 'grid_import': 0}
# episode:270 Profit:0
# 3
# 30 43 100 113
# {'grid_export': 0, 'grid_import': 0}
# 2
# 43 28 132 102
# {'grid_export': 0, 'grid_import': 15}
# 1
# 28 26 104 102
# {'grid_export': 0, 'grid_import': 0}
# 3
# 26 15 139 128
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 0 143 86
# {'grid_export': 0, 'grid_import': 0}
# episode:271 Profit:-150
# 3
# 30 16 135 121
# {'grid_export': 0, 'grid_import': 0}
# 2
# 16 1 131 88
# {'grid_export': 0, 'grid_import': 28}
# episode:272 Profit:-280
# 3
# 30 15 126 88
# {'grid_export': 0, 'grid_import': 23}
# 1
# 15 21 120 126
# {'grid_export': 0, 'grid_import': 0}
# 2
# 21 6 116 126
# {'grid_export': 0, 'grid_import': 0}
# episode:273 Profit:-230
# 2
# 30 15 116 121
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 0 123 86
# {'grid_export': 0, 'grid_import': 0}
# episode:274 Profit:0
# 0
# 30 3 124 97
# {'grid_export': 0, 'grid_import': 0}
# episode:275 Profit:0
# 2
# 30 15 121 125
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 21 120 126
# {'grid_export': 0, 'grid_import': 0}
# 0
# 21 22 104 105
# {'grid_export': 0, 'grid_import': 0}
# 1
# 22 0 132 90
# {'grid_export': 0, 'grid_import': 0}
# episode:276 Profit:0
# 0
# 30 0 123 86
# {'grid_export': 0, 'grid_import': 0}
# episode:277 Profit:0
# 2
# 30 15 112 122
# {'grid_export': 0, 'grid_import': 0}
# 3
# 15 0 134 112
# {'grid_export': 0, 'grid_import': 7}
# episode:278 Profit:-70
# 3
# 30 23 126 119
# {'grid_export': 0, 'grid_import': 0}
# 0
# 23 33 108 121
# {'grid_export': 3, 'grid_import': 0}
# 1
# 33 0 128 89
# {'grid_export': 0, 'grid_import': 0}
# episode:279 Profit:24
# 2
# 30 15 106 122
# {'grid_export': 0, 'grid_import': 0}
# 0
# 15 0 142 107
# {'grid_export': 0, 'grid_import': 0}
# episode:280 Profit:0
# 1
# 30 21 102 93
# {'grid_export': 0, 'grid_import': 0}
# 2
# 21 6 105 129
# {'grid_export': 0, 'grid_import': 0}
# episode:281 Profit:0
# 2
# 30 15 117 107
# {'grid_export': 0, 'grid_import': 0}
# 3
# 15 0 139 113
# {'grid_export': 0, 'grid_import': 11}
# episode:282 Profit:-110
# 3
# 30 32 108 110
# {'grid_export': 0, 'grid_import': 0}
# 1
# 32 0 142 101
# {'grid_export': 0, 'grid_import': 0}
# episode:283 Profit:0
# 3
# 30 41 115 126
# {'grid_export': 0, 'grid_import': 0}
# 0
# 41 22 142 123
# {'grid_export': 0, 'grid_import': 0}
# 3
# 22 7 123 80
# {'grid_export': 0, 'grid_import': 28}
# 2
# 7 0 133 87
# {'grid_export': 0, 'grid_import': 31}
# episode:284 Profit:-590
# 2
# 30 15 113 87
# {'grid_export': 0, 'grid_import': 11}
# 2
# 15 0 106 117
# {'grid_export': 0, 'grid_import': 0}
# episode:285 Profit:-110
# 3
# 30 15 106 85
# {'grid_export': 0, 'grid_import': 6}
# 0
# 15 25 102 128
# {'grid_export': 16, 'grid_import': 0}
# 1
# 25 19 111 105
# {'grid_export': 0, 'grid_import': 0}
# 2
# 19 4 108 120
# {'grid_export': 0, 'grid_import': 0}
# episode:286 Profit:68
# 2
# 30 15 116 107
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 3 119 107
# {'grid_export': 0, 'grid_import': 0}
# episode:287 Profit:0
# 0
# 30 39 100 109
# {'grid_export': 0, 'grid_import': 0}
# 3
# 39 32 114 107
# {'grid_export': 0, 'grid_import': 0}
# 2
# 32 17 123 93
# {'grid_export': 0, 'grid_import': 15}
# 3
# 17 2 122 90
# {'grid_export': 0, 'grid_import': 17}
# episode:288 Profit:-320
# 3
# 30 15 143 111
# {'grid_export': 0, 'grid_import': 17}
# 3
# 15 0 139 105
# {'grid_export': 0, 'grid_import': 19}
# episode:289 Profit:-360
# 3
# 30 15 122 98
# {'grid_export': 0, 'grid_import': 9}
# 0
# 15 0 140 92
# {'grid_export': 0, 'grid_import': 0}
# episode:290 Profit:-90
# 0
# 30 0 146 100
# {'grid_export': 0, 'grid_import': 0}
# episode:291 Profit:0
# 1
# 30 27 113 110
# {'grid_export': 0, 'grid_import': 0}
# 3
# 27 12 145 104
# {'grid_export': 0, 'grid_import': 26}
# 0
# 12 0 115 101
# {'grid_export': 0, 'grid_import': 0}
# episode:292 Profit:-260
# 3
# 30 15 108 82
# {'grid_export': 0, 'grid_import': 11}
# 1
# 15 0 114 99
# {'grid_export': 0, 'grid_import': 0}
# episode:293 Profit:-110
# 2
# 30 15 139 109
# {'grid_export': 0, 'grid_import': 15}
# 2
# 15 0 116 122
# {'grid_export': 0, 'grid_import': 0}
# episode:294 Profit:-150
# 2
# 30 15 145 128
# {'grid_export': 0, 'grid_import': 2}
# 1
# 15 7 119 111
# {'grid_export': 0, 'grid_import': 0}
# 3
# 7 0 143 100
# {'grid_export': 0, 'grid_import': 28}
# episode:295 Profit:-300
# 1
# 30 15 111 96
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 17 125 127
# {'grid_export': 0, 'grid_import': 0}
# 3
# 17 2 127 83
# {'grid_export': 0, 'grid_import': 29}
# episode:296 Profit:-290
# 2
# 30 15 121 88
# {'grid_export': 0, 'grid_import': 18}
# 2
# 15 0 125 98
# {'grid_export': 0, 'grid_import': 12}
# episode:297 Profit:-300
# 1
# 30 0 135 101
# {'grid_export': 0, 'grid_import': 0}
# episode:298 Profit:0
# 1
# 30 34 110 114
# {'grid_export': 0, 'grid_import': 0}
# 0
# 34 20 115 101
# {'grid_export': 0, 'grid_import': 0}
# 0
# 20 0 124 88
# {'grid_export': 0, 'grid_import': 0}
# episode:299 Profit:0
# 3
# 30 15 146 123
# {'grid_export': 0, 'grid_import': 8}
# 3
# 15 0 149 120
# {'grid_export': 0, 'grid_import': 14}
# episode:300 Profit:-220
# 1
# 30 0 149 108
# {'grid_export': 0, 'grid_import': 0}
# episode:301 Profit:0
# 3
# 30 15 118 88
# {'grid_export': 0, 'grid_import': 15}
# 3
# 15 0 121 91
# {'grid_export': 0, 'grid_import': 15}
# episode:302 Profit:-300
# 3
# 30 22 111 103
# {'grid_export': 0, 'grid_import': 0}
# 3
# 22 27 108 113
# {'grid_export': 0, 'grid_import': 0}
# 1
# 27 25 105 103
# {'grid_export': 0, 'grid_import': 0}
# 3
# 25 10 131 105
# {'grid_export': 0, 'grid_import': 11}
# 1
# 10 0 141 87
# {'grid_export': 0, 'grid_import': 0}
# episode:303 Profit:-110
# 0
# 30 0 147 117
# {'grid_export': 0, 'grid_import': 0}
# episode:304 Profit:0
# 3
# 30 23 128 121
# {'grid_export': 0, 'grid_import': 0}
# 0
# 23 0 117 85
# {'grid_export': 0, 'grid_import': 0}
# episode:305 Profit:0
# 0
# 30 0 138 89
# {'grid_export': 0, 'grid_import': 0}
# episode:306 Profit:0
# 1
# 30 18 100 88
# {'grid_export': 0, 'grid_import': 0}
# 2
# 18 3 132 113
# {'grid_export': 0, 'grid_import': 4}
# episode:307 Profit:-40
# 0
# 30 0 134 83
# {'grid_export': 0, 'grid_import': 0}
# episode:308 Profit:0
# 2
# 30 15 132 112
# {'grid_export': 0, 'grid_import': 5}
# 0
# 15 1 140 126
# {'grid_export': 0, 'grid_import': 0}
# episode:309 Profit:-50
# 1
# 30 17 102 89
# {'grid_export': 0, 'grid_import': 0}
# 0
# 17 0 120 95
# {'grid_export': 0, 'grid_import': 0}
# episode:310 Profit:0
# 3
# 30 32 104 106
# {'grid_export': 0, 'grid_import': 0}
# 3
# 32 38 117 123
# {'grid_export': 0, 'grid_import': 0}
# 3
# 38 24 125 111
# {'grid_export': 0, 'grid_import': 0}
# 0
# 24 22 129 127
# {'grid_export': 0, 'grid_import': 0}
# 2
# 22 7 137 103
# {'grid_export': 0, 'grid_import': 19}
# 0
# 7 0 143 107
# {'grid_export': 0, 'grid_import': 0}
# episode:311 Profit:-190
# 2
# 30 15 107 86
# {'grid_export': 0, 'grid_import': 6}
# 2
# 15 0 130 111
# {'grid_export': 0, 'grid_import': 4}
# episode:312 Profit:-100
# 0
# 30 0 143 89
# {'grid_export': 0, 'grid_import': 0}
# episode:313 Profit:0
# 1
# 30 6 122 98
# {'grid_export': 0, 'grid_import': 0}
# episode:314 Profit:0
# 2
# 30 15 111 120
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 15 101 101
# {'grid_export': 0, 'grid_import': 0}
# 2
# 15 0 109 126
# {'grid_export': 0, 'grid_import': 0}
# episode:315 Profit:0
# 1
# 30 19 109 98
# {'grid_export': 0, 'grid_import': 0}
# 2
# 19 4 145 123
# {'grid_export': 0, 'grid_import': 7}
# episode:316 Profit:-70
# 0
# 30 0 140 99
# {'grid_export': 0, 'grid_import': 0}
# episode:317 Profit:0
# 2
# 30 15 144 95
# {'grid_export': 0, 'grid_import': 34}
# 3
# 15 0 127 100
# {'grid_export': 0, 'grid_import': 12}
# episode:318 Profit:-460
# 0
# 30 22 113 105
# {'grid_export': 0, 'grid_import': 0}
# 3
# 22 7 105 80
# {'grid_export': 0, 'grid_import': 10}
# 3
# 7 12 102 107
# {'grid_export': 0, 'grid_import': 0}
# 1
# 12 4 106 98
# {'grid_export': 0, 'grid_import': 0}
# episode:319 Profit:-100
# 3
# 30 15 135 100
# {'grid_export': 0, 'grid_import': 20}
# 2
# 15 0 115 85
# {'grid_export': 0, 'grid_import': 15}
# episode:320 Profit:-350
# 1
# 30 8 142 120
# {'grid_export': 0, 'grid_import': 0}
# 3
# 8 11 108 111
# {'grid_export': 0, 'grid_import': 0}
# 3
# 11 23 102 114
# {'grid_export': 0, 'grid_import': 0}
# 1
# 23 0 134 102
# {'grid_export': 0, 'grid_import': 0}
# episode:321 Profit:0
# 2
# 30 15 144 100
# {'grid_export': 0, 'grid_import': 29}
# 2
# 15 0 110 120
# {'grid_export': 0, 'grid_import': 0}
# episode:322 Profit:-290
# 2
# 30 15 106 84
# {'grid_export': 0, 'grid_import': 7}
# 1
# 15 0 131 86
# {'grid_export': 0, 'grid_import': 0}
# episode:323 Profit:-70
# 2
# 30 15 103 113
# {'grid_export': 0, 'grid_import': 0}
# 2
# 15 0 138 123
# {'grid_export': 0, 'grid_import': 0}
# episode:324 Profit:0
# 2
# 30 15 113 119
# {'grid_export': 0, 'grid_import': 0}
# 3
# 15 0 110 86
# {'grid_export': 0, 'grid_import': 9}
# episode:325 Profit:-90
# 1
# 30 0 136 97
# {'grid_export': 0, 'grid_import': 0}
# episode:326 Profit:0
# 1
# 30 0 145 96
# {'grid_export': 0, 'grid_import': 0}
# episode:327 Profit:0
# 2
# 30 15 142 113
# {'grid_export': 0, 'grid_import': 14}
# 1
# 15 9 104 98
# {'grid_export': 0, 'grid_import': 0}
# 3
# 9 0 143 106
# {'grid_export': 0, 'grid_import': 22}
# episode:328 Profit:-360
# 2
# 30 15 145 84
# {'grid_export': 0, 'grid_import': 46}
# 2
# 15 0 118 127
# {'grid_export': 0, 'grid_import': 0}
# episode:329 Profit:-460
# 3
# 30 15 134 82
# {'grid_export': 0, 'grid_import': 37}
# 0
# 15 6 119 110
# {'grid_export': 0, 'grid_import': 0}
# episode:330 Profit:-370
# 0
# 30 13 102 85
# {'grid_export': 0, 'grid_import': 0}
# 3
# 13 0 149 124
# {'grid_export': 0, 'grid_import': 10}
# episode:331 Profit:-100
# 0
# 30 40 111 123
# {'grid_export': 2, 'grid_import': 0}
# 1
# 40 32 100 92
# {'grid_export': 0, 'grid_import': 0}
# 0
# 32 42 100 115
# {'grid_export': 5, 'grid_import': 0}
# 3
# 42 27 123 87
# {'grid_export': 0, 'grid_import': 21}
# 0
# 27 36 118 127
# {'grid_export': 0, 'grid_import': 0}
# 0
# 36 26 120 110
# {'grid_export': 0, 'grid_import': 0}
# 2
# 26 11 129 99
# {'grid_export': 0, 'grid_import': 15}
# 0
# 11 0 126 111
# {'grid_export': 0, 'grid_import': 0}
# episode:332 Profit:-304
# 3
# 30 25 132 127
# {'grid_export': 0, 'grid_import': 0}
# 3
# 25 10 130 85
# {'grid_export': 0, 'grid_import': 30}
# 1
# 10 14 102 106
# {'grid_export': 0, 'grid_import': 0}
# 3
# 14 0 144 119
# {'grid_export': 0, 'grid_import': 10}
# episode:333 Profit:-400
# 3
# 30 15 142 122
# {'grid_export': 0, 'grid_import': 5}
# 2
# 15 0 145 111
# {'grid_export': 0, 'grid_import': 19}
# episode:334 Profit:-240
# 3
# 30 15 106 88
# {'grid_export': 0, 'grid_import': 3}
# 0
# 15 0 127 96
# {'grid_export': 0, 'grid_import': 0}
# episode:335 Profit:-30
# 1
# 30 7 141 118
# {'grid_export': 0, 'grid_import': 0}
# 0
# 7 2 120 115
# {'grid_export': 0, 'grid_import': 0}
# episode:336 Profit:0
# 1
# 30 0 149 113
# {'grid_export': 0, 'grid_import': 0}
# episode:337 Profit:0
# 3
# 30 15 133 104
# {'grid_export': 0, 'grid_import': 14}
# 1
# 15 0 136 108
# {'grid_export': 0, 'grid_import': 0}
# episode:338 Profit:-140
# 3
# 30 40 100 110
# {'grid_export': 0, 'grid_import': 0}
# 0
# 40 0 146 94
# {'grid_export': 0, 'grid_import': 0}
# episode:339 Profit:0
# 1
# 30 0 144 91
# {'grid_export': 0, 'grid_import': 0}
# episode:340 Profit:0
# 3
# 30 22 103 95
# {'grid_export': 0, 'grid_import': 0}
# 1
# 22 0 111 89
# {'grid_export': 0, 'grid_import': 0}
# episode:341 Profit:0
# 2
# 30 15 148 101
# {'grid_export': 0, 'grid_import': 32}
# 0
# 15 0 149 99
# {'grid_export': 0, 'grid_import': 0}
# episode:342 Profit:-320
# 0
# 30 40 109 129
# {'grid_export': 10, 'grid_import': 0}
# 3
# 40 30 104 94
# {'grid_export': 0, 'grid_import': 0}
# 3
# 30 15 137 94
# {'grid_export': 0, 'grid_import': 28}
# 2
# 15 0 109 116
# {'grid_export': 0, 'grid_import': 0}
# episode:343 Profit:-200
# 0
# 30 0 126 90
# {'grid_export': 0, 'grid_import': 0}
# episode:344 Profit:0
# 1
# 30 0 137 102
# {'grid_export': 0, 'grid_import': 0}
# episode:345 Profit:0
# 1
# 30 0 144 86
# {'grid_export': 0, 'grid_import': 0}
# episode:346 Profit:0
# 1
# 30 12 141 123
# {'grid_export': 0, 'grid_import': 0}
# 1
# 12 0 134 90
# {'grid_export': 0, 'grid_import': 0}
# episode:347 Profit:0
# 2
# 30 15 148 81
# {'grid_export': 0, 'grid_import': 52}
# 3
# 15 0 119 100
# {'grid_export': 0, 'grid_import': 4}
# episode:348 Profit:-560
# 3
# 30 15 140 103
# {'grid_export': 0, 'grid_import': 22}
# 2
# 15 0 144 128
# {'grid_export': 0, 'grid_import': 1}
# episode:349 Profit:-230
# 0
# 30 8 117 95
# {'grid_export': 0, 'grid_import': 0}
# 1
# 8 0 134 91
# {'grid_export': 0, 'grid_import': 0}
# episode:350 Profit:0
# 1
# 30 38 109 117
# {'grid_export': 0, 'grid_import': 0}
# 1
# 38 0 130 85
# {'grid_export': 0, 'grid_import': 0}
# episode:351 Profit:0
# 2
# 30 15 135 117
# {'grid_export': 0, 'grid_import': 3}
# 3
# 15 27 115 127
# {'grid_export': 0, 'grid_import': 0}
# 2
# 27 12 134 88
# {'grid_export': 0, 'grid_import': 31}
# 1
# 12 0 113 101
# {'grid_export': 0, 'grid_import': 0}
# episode:352 Profit:-340
# 1
# 30 12 138 120
# {'grid_export': 0, 'grid_import': 0}
# 3
# 12 30 101 119
# {'grid_export': 0, 'grid_import': 0}
# 2
# 30 15 141 111
# {'grid_export': 0, 'grid_import': 15}
# 2
# 15 0 143 114
# {'grid_export': 0, 'grid_import': 14}
# episode:353 Profit:-290
# 3
# 30 15 148 100
# {'grid_export': 0, 'grid_import': 33}
# 3
# 15 0 124 87
# {'grid_export': 0, 'grid_import': 22}
# episode:354 Profit:-550
# 1
# 30 0 145 100
# {'grid_export': 0, 'grid_import': 0}
# episode:355 Profit:0
# 0
# 30 0 145 108
# {'grid_export': 0, 'grid_import': 0}
# episode:356 Profit:0
# 0
# 30 4 125 99
# {'grid_export': 0, 'grid_import': 0}
# episode:357 Profit:0
# 0
# 30 34 117 121
# {'grid_export': 0, 'grid_import': 0}
# 2
# 34 19 138 82
# {'grid_export': 0, 'grid_import': 41}
# 1
# 19 0 148 122
# {'grid_export': 0, 'grid_import': 0}
# episode:358 Profit:-410
# 0
# 30 0 130 91
# {'grid_export': 0, 'grid_import': 0}
# episode:359 Profit:0
# 3
# 30 15 129 90
# {'grid_export': 0, 'grid_import': 24}
# 3
# 15 2 121 108
# {'grid_export': 0, 'grid_import': 0}
# episode:360 Profit:-240
# 2
# 30 15 123 117
# {'grid_export': 0, 'grid_import': 0}
# 3
# 15 0 142 97
# {'grid_export': 0, 'grid_import': 30}
# episode:361 Profit:-300
# 1
# 30 40 101 128
# {'grid_export': 17, 'grid_import': 0}
# 3
# 40 49 110 119
# {'grid_export': 0, 'grid_import': 0}
# 1
# 49 47 121 119
# {'grid_export': 0, 'grid_import': 0}
# 1
# 47 28 112 93
# {'grid_export': 0, 'grid_import': 0}
# 0
# 28 18 130 120
# {'grid_export': 0, 'grid_import': 0}
# 1
# 18 0 124 88
# {'grid_export': 0, 'grid_import': 0}
# episode:362 Profit:136
# 3
# 30 15 139 104
# {'grid_export': 0, 'grid_import': 20}
# 3
# 15 15 103 103
# {'grid_export': 0, 'grid_import': 0}
# 0
# 15 5 115 105
# {'grid_export': 0, 'grid_import': 0}
# episode:363 Profit:-200
# 2
# 30 15 124 120
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 0 147 123
# {'grid_export': 0, 'grid_import': 0}
# episode:364 Profit:0
# 3
# 30 15 123 85
# {'grid_export': 0, 'grid_import': 23}
# 2
# 15 0 102 94
# {'grid_export': 0, 'grid_import': 0}
# episode:365 Profit:-230
# 0
# 30 8 127 105
# {'grid_export': 0, 'grid_import': 0}
# 2
# 8 0 112 88
# {'grid_export': 0, 'grid_import': 9}
# episode:366 Profit:-90
# 3
# 30 15 115 97
# {'grid_export': 0, 'grid_import': 3}
# 3
# 15 0 115 98
# {'grid_export': 0, 'grid_import': 2}
# episode:367 Profit:-50
# 2
# 30 15 115 83
# {'grid_export': 0, 'grid_import': 17}
# 3
# 15 15 124 124
# {'grid_export': 0, 'grid_import': 0}
# 0
# 15 14 128 127
# {'grid_export': 0, 'grid_import': 0}
# 2
# 14 0 117 91
# {'grid_export': 0, 'grid_import': 11}
# episode:368 Profit:-280
# 1
# 30 36 116 122
# {'grid_export': 0, 'grid_import': 0}
# 2
# 36 21 141 86
# {'grid_export': 0, 'grid_import': 40}
# 1
# 21 4 117 100
# {'grid_export': 0, 'grid_import': 0}
# episode:369 Profit:-400
# 0
# 30 20 129 119
# {'grid_export': 0, 'grid_import': 0}
# 0
# 20 14 133 127
# {'grid_export': 0, 'grid_import': 0}
# 3
# 14 4 122 112
# {'grid_export': 0, 'grid_import': 0}
# episode:370 Profit:0
# 0
# 30 6 139 115
# {'grid_export': 0, 'grid_import': 0}
# episode:371 Profit:0
# 2
# 30 15 125 114
# {'grid_export': 0, 'grid_import': 0}
# 1
# 15 25 105 121
# {'grid_export': 6, 'grid_import': 0}
# 2
# 25 10 124 111
# {'grid_export': 0, 'grid_import': 0}
# 0
# 10 0 120 102
# {'grid_export': 0, 'grid_import': 0}
# episode:372 Profit:48
# 0
# 30 8 145 123
# {'grid_export': 0, 'grid_import': 0}
# 2
# 8 0 145 129
# {'grid_export': 0, 'grid_import': 1}
# episode:373 Profit:-10
# 1
# 30 14 125 109
# {'grid_export': 0, 'grid_import': 0}
# 3
# 14 0 133 98
# {'grid_export': 0, 'grid_import': 20}
# episode:374 Profit:-200
# 2
# 30 15 119 92
# {'grid_export': 0, 'grid_import': 12}
# 3
# 15 13 101 99
# {'grid_export': 0, 'grid_import': 0}
# 1
# 13 21 120 128
# {'grid_export': 0, 'grid_import': 0}
# 2
# 21 6 121 85
# {'grid_export': 0, 'grid_import': 21}
# episode:375 Profit:-330
# 1
# 30 26 128 124
# {'grid_export': 0, 'grid_import': 0}
# 0
# 26 0 142 89
# {'grid_export': 0, 'grid_import': 0}
# episode:376 Profit:0
# 3
# 30 30 129 129
# {'grid_export': 0, 'grid_import': 0}
# 3
# 30 35 124 129
# {'grid_export': 0, 'grid_import': 0}
# 0
# 35 14 103 82
# {'grid_export': 0, 'grid_import': 0}
# 3
# 14 19 123 128
# {'grid_export': 0, 'grid_import': 0}
# 0
# 19 1 139 121
# {'grid_export': 0, 'grid_import': 0}
# episode:377 Profit:0
# 3
# 30 15 143 97
# {'grid_export': 0, 'grid_import': 31}
# 2
# 15 0 148 93
# {'grid_export': 0, 'grid_import': 40}
# episode:378 Profit:-710
# 2
# 30 15 111 126
# {'grid_export': 0, 'grid_import': 0}
# 2
# 15 0 117 103
# {'grid_export': 0, 'grid_import': 0}
# episode:379 Profit:0
# 3
# 30 15 115 87
# {'grid_export': 0, 'grid_import': 13}
# 3
# 15 3 112 100
# {'grid_export': 0, 'grid_import': 0}
# episode:380 Profit:-130
# 2
# 30 15 131 124
# {'grid_export': 0, 'grid_import': 0}
# 2
# 15 0 107 89
# {'grid_export': 0, 'grid_import': 3}
# episode:381 Profit:-30
# 2
# 30 15 100 129
# {'grid_export': 0, 'grid_import': 0}
# 3
# 15 0 111 95
# {'grid_export': 0, 'grid_import': 1}
# episode:382 Profit:-10
# 1
# 30 9 105 84
# {'grid_export': 0, 'grid_import': 0}
# 1
# 9 0 126 116
# {'grid_export': 0, 'grid_import': 0}
# episode:383 Profit:0
# 0
# 30 23 107 100
# {'grid_export': 0, 'grid_import': 0}
# 1
# 23 33 105 125
# {'grid_export': 10, 'grid_import': 0}
# 1
# 33 18 100 85
# {'grid_export': 0, 'grid_import': 0}
# 1
# 18 5 135 122
# {'grid_export': 0, 'grid_import': 0}
# episode:384 Profit:80
# 1
# 30 0 145 94
# {'grid_export': 0, 'grid_import': 0}
# episode:385 Profit:0
# 2
# 30 15 117 88
# {'grid_export': 0, 'grid_import': 14}
# 0
# 15 0 125 86
# {'grid_export': 0, 'grid_import': 0}
# episode:386 Profit:-140
# 0
# 30 0 146 86
# {'grid_export': 0, 'grid_import': 0}
# episode:387 Profit:0
# 1
# 30 3 119 92
# {'grid_export': 0, 'grid_import': 0}
# episode:388 Profit:0
# 3
# 30 26 127 123
# {'grid_export': 0, 'grid_import': 0}
# 1
# 26 36 103 118
# {'grid_export': 5, 'grid_import': 0}
# 3
# 36 21 140 106
# {'grid_export': 0, 'grid_import': 19}
# 0
# 21 0 125 99
# {'grid_export': 0, 'grid_import': 0}
# episode:389 Profit:-150
# 2
# 30 15 136 102
# {'grid_export': 0, 'grid_import': 19}
# 0
# 15 0 125 80
# {'grid_export': 0, 'grid_import': 0}
# episode:390 Profit:-190
# 1
# 30 30 109 109
# {'grid_export': 0, 'grid_import': 0}
# 3
# 30 32 106 108
# {'grid_export': 0, 'grid_import': 0}
# 0
# 32 19 106 93
# {'grid_export': 0, 'grid_import': 0}
# 1
# 19 0 133 97
# {'grid_export': 0, 'grid_import': 0}
# episode:391 Profit:0
# 1
# 30 0 141 103
# {'grid_export': 0, 'grid_import': 0}
# episode:392 Profit:0
# 1
# 30 0 147 84
# {'grid_export': 0, 'grid_import': 0}
# episode:393 Profit:0
# 0
# 30 25 110 105
# {'grid_export': 0, 'grid_import': 0}
# 0
# 25 0 145 99
# {'grid_export': 0, 'grid_import': 0}
# episode:394 Profit:0
# 0
# 30 32 112 114
# {'grid_export': 0, 'grid_import': 0}
# 1
# 32 0 148 107
# {'grid_export': 0, 'grid_import': 0}
# episode:395 Profit:0
# 1
# 30 9 145 124
# {'grid_export': 0, 'grid_import': 0}
# 3
# 9 0 135 91
# {'grid_export': 0, 'grid_import': 29}
# episode:396 Profit:-290
# 2
# 30 15 147 129
# {'grid_export': 0, 'grid_import': 3}
# 0
# 15 0 117 89
# {'grid_export': 0, 'grid_import': 0}
# episode:397 Profit:-30
# 2
# 30 15 144 115
# {'grid_export': 0, 'grid_import': 14}
# 3
# 15 0 131 88
# {'grid_export': 0, 'grid_import': 28}
# episode:398 Profit:-420
# 1
# 30 0 148 82
# {'grid_export': 0, 'grid_import': 0}
# episode:399 Profit:0
